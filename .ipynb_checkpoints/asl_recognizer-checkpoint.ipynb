# %% [markdown]
# # Artificial Intelligence Engineer Nanodegree - Probabilistic Models
# ## Project: Sign Language Recognition System
# - [Introduction](#intro)
# - [Part 1 Feature Selection](#part1_tutorial)
#     - [Tutorial](#part1_tutorial)
#     - [Features Submission](#part1_submission)
#     - [Features Unittest](#part1_test)
# - [Part 2 Train the models](#part2_tutorial)
#     - [Tutorial](#part2_tutorial)
#     - [Model Selection Score Submission](#part2_submission)
#     - [Model Score Unittest](#part2_test)
# - [Part 3 Build a Recognizer](#part3_tutorial)
#     - [Tutorial](#part3_tutorial)
#     - [Recognizer Submission](#part3_submission)
#     - [Recognizer Unittest](#part3_test)
# - [Part 4 (OPTIONAL) Improve the WER with Language Models](#part4_info)

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# The overall goal of this project is to build a word recognizer for American Sign Language video sequences, demonstrating the power of probabalistic models.  In particular, this project employs  [hidden Markov models (HMM's)](https://en.wikipedia.org/wiki/Hidden_Markov_model) to analyze a series of measurements taken from videos of American Sign Language (ASL) collected for research (see the [RWTH-BOSTON-104 Database](http://www-i6.informatik.rwth-aachen.de/~dreuw/database-rwth-boston-104.php)).  In this video, the right-hand x and y locations are plotted as the speaker signs the sentence.
# [![ASLR demo](http://www-i6.informatik.rwth-aachen.de/~dreuw/images/demosample.png)](https://drive.google.com/open?id=0B_5qGuFe-wbhUXRuVnNZVnMtam8)
#
# The raw data, train, and test sets are pre-defined.  You will derive a variety of feature sets (explored in Part 1), as well as implement three different model selection criterion to determine the optimal number of hidden states for each word model (explored in Part 2). Finally, in Part 3 you will implement the recognizer and compare the effects the different combinations of feature sets and model selection criteria.
#
# At the end of each Part, complete the submission cells with implementations, answer all questions, and pass the unit tests.  Then submit the completed notebook for review!

# %% [markdown]
# <a id='part1_tutorial'></a>
# ## PART 1: Data
#
# ### Features Tutorial
# ##### Load the initial database
# A data handler designed for this database is provided in the student codebase as the `AslDb` class in the `asl_data` module.  This handler creates the initial [pandas](http://pandas.pydata.org/pandas-docs/stable/) dataframe from the corpus of data included in the `data` directory as well as dictionaries suitable for extracting data in a format friendly to the [hmmlearn](https://hmmlearn.readthedocs.io/en/latest/) library.  We'll use those to create models in Part 2.
#
# To start, let's set up the initial database and select an example set of features for the training set.  At the end of Part 1, you will create additional feature sets for experimentation.

# %%
import numpy as np
import pandas as pd
from asl_data import AslDb


asl = AslDb() # initializes the database
asl.df.head() # displays the first five rows of the asl database, indexed by video and frame
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1

# %%
asl.df.ix[98,1]  # look at the data available for an individual frame
# Out:
# left-x         149
# left-y         181
# right-x        170
# right-y        175
# nose-x         161
# nose-y          62
# speaker    woman-1
# Name: (98, 1), dtype: object

# %% [markdown]
# The frame represented by video 98, frame 1 is shown here:
# ![Video 98](http://www-i6.informatik.rwth-aachen.de/~dreuw/database/rwth-boston-104/overview/images/orig/098-start.jpg)

# %% [markdown]
# ##### Feature selection for training the model
# The objective of feature selection when training a model is to choose the most relevant variables while keeping the model as simple as possible, thus reducing training time.  We can use the raw features already provided or derive our own and add columns to the pandas dataframe `asl.df` for selection. As an example, in the next cell a feature named `'grnd-ry'` is added. This feature is the difference between the right-hand y value and the nose y value, which serves as the "ground" right y value.

# %%
asl.df['grnd-ry'] = asl.df['right-y'] - asl.df['nose-y']
asl.df.head()  # the new feature 'grnd-ry' is now in the frames dictionary
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry
# video frame
# 98    0          113
#       1          113
#       2          113
#       3          113
#       4          113

# %% [markdown]
# ##### Try it!

# %%
from asl_utils import test_features_tryit
# TODO add df columns for 'grnd-rx', 'grnd-ly', 'grnd-lx' representing differences between hand and nose locations
asl.df['grnd-rx'] = asl.df['right-x'] - asl.df['nose-x']
asl.df['grnd-ly'] = asl.df['left-y'] - asl.df['nose-y']
asl.df['grnd-lx'] = asl.df['left-x'] - asl.df['nose-x']

# test the code
test_features_tryit(asl)
# Out:
# asl.df sample
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx
# video frame
# 98    0          113        9      119      -12
#       1          113        9      119      -12
#       2          113        9      119      -12
#       3          113        9      119      -12
#       4          113        9      119      -12
# <font color=green>Correct!</font><br/>

# %%
# collect the features into a list
features_ground = ['grnd-rx','grnd-ry','grnd-lx','grnd-ly']
 #show a single set of features for a given (video, frame) tuple
[asl.df.ix[98,1][v] for v in features_ground]
# Out:
# [9, 113, -12, 119]

# %% [markdown]
# ##### Build the training set
# Now that we have a feature list defined, we can pass that list to the `build_training` method to collect the features for all the words in the training set.  Each word in the training set has multiple examples from various videos.  Below we can see the unique words that have been loaded into the training set:

# %%
training = asl.build_training(features_ground)
print("Training words: {}".format(training.words))
# Out:
# Training words: ['PREFER', 'JANA', 'FIND', 'BROTHER', 'CORN1', 'MARY', 'NAME', 'PUTASIDE', 'TOMORROW', 'CAR', 'BUY', 'STOLEN', 'GIVE3', 'SEE', 'SAY-1P', 'ARRIVE', 'GET', 'TEACHER', 'SOMETHING-ONE', 'LEG', 'VISIT', 'SEARCH-FOR', 'BLAME', 'WHAT', 'FRIEND', 'FRANK', 'LAST-WEEK', 'HOMEWORK', 'PAST', 'READ', 'BREAK-DOWN', 'NOT', 'GO', 'PARTY', 'DECIDE', 'CANDY', 'SUE', 'TELL', 'CHICKEN', 'MOVIE', 'LIVE', 'NEW', 'YESTERDAY', 'BOOK', 'WONT', 'BUY1', 'KNOW', 'ALL', 'POSS', 'WOMAN', 'EAT', 'BOY', 'SHOULD', 'CAN', 'POTATO', 'JOHN', 'GIVE1', 'CHINA', 'VEGETABLE', 'FRED', 'BILL', 'WILL', 'VIDEOTAPE', 'CHICAGO', 'BORROW', 'TOY1', 'HOUSE', 'GO1', 'GROUP', 'CORN', 'STUDENT', 'TOY', 'BROCCOLI', 'NEXT-WEEK', 'GIRL', 'MAN', 'LIKE', 'SELL', 'HIT', 'CHOCOLATE', 'APPLE', 'BLUE', 'IX-1P', 'MOTHER', 'FINISH', 'COAT', 'FUTURE1', 'BOX', 'WHO', 'GO2', 'SELF', 'MANY', 'LEAVE', 'THROW', 'SHOOT', 'FISH', 'SAY', 'WRITE', 'ANN', 'HAVE', 'HERE', 'OLD', 'GIVE2', 'BUT', 'WANT', 'IX', 'LOVE', 'FUTURE', 'NEW-YORK', 'THINK', 'PEOPLE', 'GIVE']

# %% [markdown]
# The training data in `training` is an object of class `WordsData` defined in the `asl_data` module.  in addition to the `words` list, data can be accessed with the `get_all_sequences`, `get_all_Xlengths`, `get_word_sequences`, and `get_word_Xlengths` methods. We need the `get_word_Xlengths` method to train multiple sequences with the `hmmlearn` library.  In the following example, notice that there are two lists; the first is a concatenation of all the sequences(the X portion) and the second is a list of the sequence lengths(the Lengths portion).

# %%
training.get_word_Xlengths('CHOCOLATE')
# Out:
# (array([[-11,  48,   7, 120],
#         [-11,  48,   8, 109],
#         [ -8,  49,  11,  98],
#         [ -7,  50,   7,  87],
#         [ -4,  54,   7,  77],
#         [ -4,  54,   6,  69],
#         [ -4,  54,   6,  69],
#         [-13,  52,   6,  69],
#         [-13,  52,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [-10,  59,   7,  71],
#         [-15,  64,   9,  77],
#         [-17,  75,  13,  81],
#         [ -4,  48,  -4, 113],
#         [ -2,  53,  -4, 113],
#         [ -4,  55,   2,  98],
#         [ -4,  58,   2,  98],
#         [ -1,  59,   2,  89],
#         [ -1,  59,  -1,  84],
#         [ -1,  59,  -1,  84],
#         [ -7,  63,  -1,  84],
#         [ -7,  63,  -1,  84],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -4,  70,   3,  83],
#         [ -4,  70,   3,  83],
#         [ -2,  73,   5,  90],
#         [ -3,  79,  -4,  96],
#         [-15,  98,  13, 135],
#         [ -6,  93,  12, 128],
#         [ -2,  89,  14, 118],
#         [  5,  90,  10, 108],
#         [  4,  86,   7, 105],
#         [  4,  86,   7, 105],
#         [  4,  86,  13, 100],
#         [ -3,  82,  14,  96],
#         [ -3,  82,  14,  96],
#         [  6,  89,  16, 100],
#         [  6,  89,  16, 100],
#         [  7,  85,  17, 111]], dtype=int64), [17, 20, 12])

# %% [markdown]
# ###### More feature sets
# So far we have a simple feature set that is enough to get started modeling.  However, we might get better results if we manipulate the raw values a bit more, so we will go ahead and set up some other options now for experimentation later.  For example, we could normalize each speaker's range of motion with grouped statistics using [Pandas stats](http://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-stats) functions and [pandas groupby](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html).  Below is an example for finding the means of all speaker subgroups.

# %%
df_means = asl.df.groupby('speaker').mean()
df_means
# Out:
#              left-x      left-y     right-x     right-y      nose-x  \
# speaker
# man-1    206.248203  218.679449  155.464350  150.371031  175.031756
# woman-1  164.661438  161.271242  151.017865  117.332462  162.655120
# woman-2  183.214509  176.527232  156.866295  119.835714  170.318973
#
#             nose-y    grnd-ry    grnd-rx     grnd-ly    grnd-lx
# speaker
# man-1    61.642600  88.728430 -19.567406  157.036848  31.216447
# woman-1  57.245098  60.087364 -11.637255  104.026144   2.006318
# woman-2  58.022098  61.813616 -13.452679  118.505134  12.895536

# %% [markdown]
# To select a mean that matches by speaker, use the pandas [map](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) method:

# %%
asl.df['left-x-mean']= asl.df['speaker'].map(df_means['left-x'])
asl.df.head()
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx  left-x-mean
# video frame
# 98    0          113        9      119      -12   164.661438
#       1          113        9      119      -12   164.661438
#       2          113        9      119      -12   164.661438
#       3          113        9      119      -12   164.661438
#       4          113        9      119      -12   164.661438

# %% [markdown]
# ##### Try it!

# %%
from asl_utils import test_std_tryit
# TODO Create a dataframe named `df_std` with standard deviations grouped by speaker
df_std = asl.df.groupby('speaker').std()

# test the code
test_std_tryit(df_std)
# Out:
# df_std
#             left-x     left-y    right-x    right-y    nose-x    nose-y  \
# speaker
# man-1    15.154425  36.328485  18.901917  54.902340  6.654573  5.520045
# woman-1  17.573442  26.594521  16.459943  34.667787  3.549392  3.538330
# woman-2  15.388711  28.825025  14.890288  39.649111  4.099760  3.416167
#
#            grnd-ry    grnd-rx    grnd-ly    grnd-lx  left-x-mean
# speaker
# man-1    53.487999  20.269032  36.572749  15.080360          0.0
# woman-1  33.972660  16.764706  27.117393  17.328941          0.0
# woman-2  39.128572  16.191324  29.320655  15.050938          0.0
# <font color=green>Correct!</font><br/>

# %% [markdown]
# <a id='part1_submission'></a>
# ### Features Implementation Submission
# Implement four feature sets and answer the question that follows.
# - normalized Cartesian coordinates
#     - use *mean* and *standard deviation* statistics and the [standard score](https://en.wikipedia.org/wiki/Standard_score) equation to account for speakers with different heights and arm length
#
# - polar coordinates
#     - calculate polar coordinates with [Cartesian to polar equations](https://en.wikipedia.org/wiki/Polar_coordinate_system#Converting_between_polar_and_Cartesian_coordinates)
#     - use the [np.arctan2](https://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.arctan2.html) function and *swap the x and y axes* to move the $0$ to $2\pi$ discontinuity to 12 o'clock instead of 3 o'clock;  in other words, the normal break in radians value from $0$ to $2\pi$ occurs directly to the left of the speaker's nose, which may be in the signing area and interfere with results.  By swapping the x and y axes, that discontinuity move to directly above the speaker's head, an area not generally used in signing.
#
# - delta difference
#     - as described in Thad's lecture, use the difference in values between one frame and the next frames as features
#     - pandas [diff method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.diff.html) and [fillna method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html) will be helpful for this one
#
# - custom features
#     - These are your own design; combine techniques used above or come up with something else entirely. We look forward to seeing what you come up with!
#     Some ideas to get you started:
#         - normalize using a [feature scaling equation](https://en.wikipedia.org/wiki/Feature_scaling)
#         - normalize the polar coordinates
#         - adding additional deltas

# %%
# TODO add features for normalized by speaker values of left, right, x, y
# Name these 'norm-rx', 'norm-ry', 'norm-lx', and 'norm-ly'
# using Z-score scaling (X-Xmean)/Xstd

asl.df['left-y-mean'] = asl.df['speaker'].map(df_means['left-y'])
asl.df['right-x-mean'] = asl.df['speaker'].map(df_means['right-x'])
asl.df['right-y-mean'] = asl.df['speaker'].map(df_means['right-y'])
asl.df['nose-x-mean'] = asl.df['speaker'].map(df_means['nose-x'])
asl.df['nose-y-mean'] = asl.df['speaker'].map(df_means['nose-y'])
asl.df['grnd-lx-mean'] = asl.df['speaker'].map(df_means['grnd-lx'])
asl.df['grnd-rx-mean'] = asl.df['speaker'].map(df_means['grnd-rx'])
asl.df['grnd-ly-mean'] = asl.df['speaker'].map(df_means['grnd-ly'])
asl.df['grnd-ry-mean'] = asl.df['speaker'].map(df_means['grnd-ry'])
asl.df['left-x-std'] = asl.df['speaker'].map(df_std['left-x'])
asl.df['left-y-std'] = asl.df['speaker'].map(df_std['left-y'])
asl.df['right-x-std'] = asl.df['speaker'].map(df_std['right-x'])
asl.df['right-y-std'] = asl.df['speaker'].map(df_std['right-y'])
asl.df['nose-x-std'] = asl.df['speaker'].map(df_std['nose-x'])
asl.df['nose-y-std'] = asl.df['speaker'].map(df_std['nose-y'])
asl.df['grnd-lx-std'] = asl.df['speaker'].map(df_std['grnd-lx'])
asl.df['grnd-rx-std'] = asl.df['speaker'].map(df_std['grnd-rx'])
asl.df['grnd-ly-std'] = asl.df['speaker'].map(df_std['grnd-ly'])
asl.df['grnd-ry-std'] = asl.df['speaker'].map(df_std['grnd-ry'])

asl.df['norm-lx'] = (asl.df['left-x'] - asl.df['left-x-mean'])/asl.df['left-x-std']
asl.df['norm-ly'] = (asl.df['left-y'] - asl.df['left-y-mean'])/asl.df['left-y-std']
asl.df['norm-rx'] = (asl.df['right-x'] - asl.df['right-x-mean'])/asl.df['right-x-std']
asl.df['norm-ry'] = (asl.df['right-y'] - asl.df['right-y-mean'])/asl.df['right-y-std']

features_norm = ['norm-rx', 'norm-ry', 'norm-lx','norm-ly']

# %%
# TODO add features for polar coordinate values where the nose is the origin
# Name these 'polar-rr', 'polar-rtheta', 'polar-lr', and 'polar-ltheta'
# Note that 'polar-rr' and 'polar-rtheta' refer to the radius and angle

asl.df['polar-rr'] = np.power(np.power(asl.df['grnd-rx'],2) + np.power(asl.df['grnd-ry'],2), 0.5)
asl.df['polar-lr'] = np.power(np.power(asl.df['grnd-lx'],2) + np.power(asl.df['grnd-ly'],2), 0.5)
asl.df['polar-rtheta'] = np.arctan2(asl.df['grnd-rx'],asl.df['grnd-ry'])
asl.df['polar-ltheta'] = np.arctan2(asl.df['grnd-lx'],asl.df['grnd-ly'])
features_polar = ['polar-rr', 'polar-rtheta', 'polar-lr', 'polar-ltheta']

# %%
# TODO add features for left, right, x, y differences by one time step, i.e. the "delta" values discussed in the lecture
# Name these 'delta-rx', 'delta-ry', 'delta-lx', and 'delta-ly'

asl.df['delta-rx'] = (asl.df['right-x'] - asl.df['right-x'].shift(1)).fillna(0)
asl.df['delta-ry'] = (asl.df['right-y'] - asl.df['right-y'].shift(1)).fillna(0)
asl.df['delta-lx'] = (asl.df['left-x'] - asl.df['left-x'].shift(1)).fillna(0)
asl.df['delta-ly'] = (asl.df['left-y'] - asl.df['left-y'].shift(1)).fillna(0)
features_delta = ['delta-rx', 'delta-ry', 'delta-lx', 'delta-ly']

# %% [markdown]
# **Question 1:**  What custom features did you choose for the features_custom set and why?
#
# **Answer 1:** Instead of just a 1 frame delay, I added a 2 frame delay in computing the differences. Additional delays lead to better caputuring of the dependencies of movements over time.

# %%
# TODO add features of your own design, which may be a combination of the above or something else
# Name these whatever you would like
asl.df['delta-rx-2'] = (asl.df['right-x'] - asl.df['right-x'].shift(2)).fillna(0)
asl.df['delta-ry-2'] = (asl.df['right-y'] - asl.df['right-y'].shift(2)).fillna(0)
asl.df['delta-lx-2'] = (asl.df['left-x'] - asl.df['left-x'].shift(2)).fillna(0)
asl.df['delta-ly-2'] = (asl.df['left-y'] - asl.df['left-y'].shift(2)).fillna(0)
# TODO define a list named 'features_custom' for building the training set
features_custom = ['delta-rx-2','delta-ry-2','delta-lx-2','delta-ly-2']

# %% [markdown]
# <a id='part1_test'></a>
# ### Features Unit Testing
# Run the following unit tests as a sanity check on the defined "ground", "norm", "polar", and 'delta"
# feature sets.  The test simply looks for some valid values but is not exhaustive.  However, the project should not be submitted if these tests don't pass.

# %%
import unittest
# import numpy as np

class TestFeatures(unittest.TestCase):

    def test_features_ground(self):
        sample = (asl.df.ix[98, 1][features_ground]).tolist()
        self.assertEqual(sample, [9, 113, -12, 119])

    def test_features_norm(self):
        sample = (asl.df.ix[98, 1][features_norm]).tolist()
        np.testing.assert_almost_equal(sample, [ 1.153,  1.663, -0.891,  0.742], 3)

    def test_features_polar(self):
        sample = (asl.df.ix[98,1][features_polar]).tolist()
        np.testing.assert_almost_equal(sample, [113.3578, 0.0794, 119.603, -0.1005], 3)

    def test_features_delta(self):
        sample = (asl.df.ix[98, 0][features_delta]).tolist()
        self.assertEqual(sample, [0, 0, 0, 0])
        sample = (asl.df.ix[98, 18][features_delta]).tolist()
        self.assertTrue(sample in [[-16, -5, -2, 4], [-14, -9, 0, 0]], "Sample value found was {}".format(sample))
                         
suite = unittest.TestLoader().loadTestsFromModule(TestFeatures())
unittest.TextTestRunner().run(suite)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.165s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>

# %% [markdown]
# <a id='part2_tutorial'></a>
# ## PART 2: Model Selection
# ### Model Selection Tutorial
# The objective of Model Selection is to tune the number of states for each word HMM prior to testing on unseen data.  In this section you will explore three methods:
# - Log likelihood using cross-validation folds (CV)
# - Bayesian Information Criterion (BIC)
# - Discriminative Information Criterion (DIC)

# %% [markdown]
# ##### Train a single word
# Now that we have built a training set with sequence data, we can "train" models for each word.  As a simple starting example, we train a single word using Gaussian hidden Markov models (HMM).   By using the `fit` method during training, the [Baum-Welch Expectation-Maximization](https://en.wikipedia.org/wiki/Baum%E2%80%93Welch_algorithm) (EM) algorithm is invoked iteratively to find the best estimate for the model *for the number of hidden states specified* from a group of sample seequences. For this example, we *assume* the correct number of hidden states is 3, but that is just a guess.  How do we know what the "best" number of states for training is?  We will need to find some model selection technique to choose the best parameter.

# %%
import warnings
from hmmlearn.hmm import GaussianHMM

def train_a_word(word, num_hidden_states, features):
    
    warnings.filterwarnings("ignore", category=DeprecationWarning)
    training = asl.build_training(features)  
    X, lengths = training.get_word_Xlengths(word)
    model = GaussianHMM(n_components=num_hidden_states, n_iter=1000).fit(X, lengths)
    logL = model.score(X, lengths)
    return model, logL

demoword = 'BOOK'
model, logL = train_a_word(demoword, 3, features_ground)
print("Number of states trained in model for {} is {}".format(demoword, model.n_components))
print("logL = {}".format(logL))
# Out:
# Number of states trained in model for BOOK is 3
# logL = -2331.1138127433196

# %% [markdown]
# The HMM model has been trained and information can be pulled from the model, including means and variances for each feature and hidden state.  The [log likelihood](http://math.stackexchange.com/questions/892832/why-we-consider-log-likelihood-instead-of-likelihood-in-gaussian-distribution) for any individual sample or group of samples can also be calculated with the `score` method.

# %%
def show_model_stats(word, model):
    print("Number of states trained in model for {} is {}".format(word, model.n_components))    
    variance=np.array([np.diag(model.covars_[i]) for i in range(model.n_components)])    
    for i in range(model.n_components):  # for each hidden state
        print("hidden state #{}".format(i))
        print("mean = ", model.means_[i])
        print("variance = ", variance[i])
        print()
    
show_model_stats(demoword, model)
# Out:
# Number of states trained in model for BOOK is 3
# hidden state #0
# mean =  [ -11.45300909   94.109178     19.03512475  102.2030162 ]
# variance =  [  77.403668    203.35441965   26.68898447  156.12444034]
#
# hidden state #1
# mean =  [ -3.46504869  50.66686933  14.02391587  52.04731066]
# variance =  [ 49.12346305  43.04799144  39.35109609  47.24195772]
#
# hidden state #2
# mean =  [ -1.12415027  69.44164191  17.02866283  77.7231196 ]
# variance =  [ 19.70434594  16.83041492  30.51552305  11.03678246]

# %% [markdown]
# ##### Try it!
# Experiment by changing the feature set, word, and/or num_hidden_states values in the next cell to see changes in values.

# %%
my_testword = 'CHOCOLATE'
model, logL = train_a_word(my_testword, 4, features_ground) # Experiment here with different parameters
show_model_stats(my_testword, model)
print("logL = {}".format(logL))
# Out:
# Number of states trained in model for CHOCOLATE is 4
# hidden state #0
# mean =  [ -9.23835975  55.307463     6.92298661  71.30538347]
# variance =  [ 16.30887738  45.97071639   3.76856896  15.98215464]
#
# hidden state #1
# mean =  [   0.58333258   87.91666611   12.75000001  108.49999882]
# variance =  [  39.4105671    18.74389523    9.85499958  144.41752618]
#
# hidden state #2
# mean =  [ -4.93681705  64.73171915   1.62598519  84.91459657]
# variance =  [  6.1617479   28.36616959   5.47102461  13.11696032]
#
# hidden state #3
# mean =  [  -6.37712306   51.09867416    3.64009161  104.46268173]
# variance =  [  10.28220014   12.44316166   27.33390004  106.91029392]
#
# logL = -565.1243334331185

# %% [markdown]
# ##### Visualize the hidden states
# We can plot the means and variances for each state and feature.  Try varying the number of states trained for the HMM model and examine the variances.  Are there some models that are "better" than others?  How can you tell?  We would like to hear what you think in the classroom online.

# %%
# %matplotlib inline

# %%
import math
from matplotlib import (cm, pyplot as plt, mlab)

def visualize(word, model):
    """ visualize the input model for a particular word """
    variance=np.array([np.diag(model.covars_[i]) for i in range(model.n_components)])
    figures = []
    for parm_idx in range(len(model.means_[0])):
        xmin = int(min(model.means_[:,parm_idx]) - max(variance[:,parm_idx]))
        xmax = int(max(model.means_[:,parm_idx]) + max(variance[:,parm_idx]))
        fig, axs = plt.subplots(model.n_components, sharex=True, sharey=False)
        colours = cm.rainbow(np.linspace(0, 1, model.n_components))
        for i, (ax, colour) in enumerate(zip(axs, colours)):
            x = np.linspace(xmin, xmax, 100)
            mu = model.means_[i,parm_idx]
            sigma = math.sqrt(np.diag(model.covars_[i])[parm_idx])
            ax.plot(x, mlab.normpdf(x, mu, sigma), c=colour)
            ax.set_title("{} feature {} hidden state #{}".format(word, parm_idx, i))

            ax.grid(True)
        figures.append(plt)
    for p in figures:
        p.show()
        
visualize(my_testword, model)

# %% [markdown]
# #####  ModelSelector class
# Review the `SelectorModel` class from the codebase found in the `my_model_selectors.py` module.  It is designed to be a strategy pattern for choosing different model selectors.  For the project submission in this section, subclass `SelectorModel` to implement the following model selectors.  In other words, you will write your own classes/functions in the `my_model_selectors.py` module and run them from this notebook:
#
# - `SelectorCV `:  Log likelihood with CV
# - `SelectorBIC`: BIC
# - `SelectorDIC`: DIC
#
# You will train each word in the training set with a range of values for the number of hidden states, and then score these alternatives with the model selector, choosing the "best" according to each strategy. The simple case of training with a constant value for `n_components` can be called using the provided `SelectorConstant` subclass as follow:

# %%
from my_model_selectors import SelectorConstant

training = asl.build_training(features_ground)  # Experiment here with different feature sets defined in part 1
word = 'VEGETABLE' # Experiment here with different words
model = SelectorConstant(training.get_all_sequences(), training.get_all_Xlengths(), word, n_constant=3).select()
print("Number of states trained in model for {} is {}".format(word, model.n_components))
# Out:
# Number of states trained in model for VEGETABLE is 3

# %% [markdown]
# ##### Cross-validation folds
# If we simply score the model with the Log Likelihood calculated from the feature sequences it has been trained on, we should expect that more complex models will have higher likelihoods. However, that doesn't tell us which would have a better likelihood score on unseen data.  The model will likely be overfit as complexity is added.  To estimate which topology model is better using only the training data, we can compare scores using cross-validation.  One technique for cross-validation is to break the training set into "folds" and rotate which fold is left out of training.  The "left out" fold scored.  This gives us a proxy method of finding the best model to use on "unseen data". In the following example, a set of word sequences is broken into three folds using the [scikit-learn Kfold](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) class object. When you implement `SelectorCV`, you will use this technique.

# %%
from sklearn.model_selection import KFold

training = asl.build_training(features_ground) # Experiment here with different feature sets
word = 'VEGETABLE' # Experiment here with different words
word_sequences = training.get_word_sequences(word)
split_method = KFold()
for cv_train_idx, cv_test_idx in split_method.split(word_sequences):
    print("Train fold indices:{} Test fold indices:{}".format(cv_train_idx, cv_test_idx))  # view indices of the folds
# Out:
# Train fold indices:[2 3 4 5] Test fold indices:[0 1]
# Train fold indices:[0 1 4 5] Test fold indices:[2 3]
# Train fold indices:[0 1 2 3] Test fold indices:[4 5]

# %%
word = 'FISH'
word_sequences = training.get_word_sequences(word)
split_method = KFold()
try:
    for cv_train_idx, cv_test_idx in split_method.split(word_sequences):
        print("Train fold indices:{} Test fold indices:{}".format(cv_train_idx, cv_test_idx))  # view indices of the folds
except ValueError:
    split_method = KFold(n_splits = 2)
    for cv_train_idx, cv_test_idx in split_method.split(word_sequences):
        print("Train fold indices:{} Test fold indices:{}".format(cv_train_idx, cv_test_idx))
# Out:
# Train fold indices:[1] Test fold indices:[0]
# Train fold indices:[0] Test fold indices:[1]

# %% [markdown]
# **Tip:** In order to run `hmmlearn` training using the X,lengths tuples on the new folds, subsets must be combined based on the indices given for the folds.  A helper utility has been provided in the `asl_utils` module named `combine_sequences` for this purpose.

# %% [markdown]
# ##### Scoring models with other criterion
# Scoring model topologies with **BIC** balances fit and complexity within the training set for each word.  In the BIC equation, a penalty term penalizes complexity to avoid overfitting, so that it is not necessary to also use cross-validation in the selection process.  There are a number of references on the internet for this criterion.  These [slides](http://www2.imm.dtu.dk/courses/02433/doc/ch6_slides.pdf) include a formula you may find helpful for your implementation.
#
# The advantages of scoring model topologies with **DIC** over BIC are presented by Alain Biem in this [reference](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.58.6208&rep=rep1&type=pdf) (also found [here](https://pdfs.semanticscholar.org/ed3d/7c4a5f607201f3848d4c02dd9ba17c791fc2.pdf)).  DIC scores the discriminant ability of a training set for one word against competing words.  Instead of a penalty term for complexity, it provides a penalty if model liklihoods for non-matching words are too similar to model likelihoods for the correct word in the word set.

# %% [markdown]
# <a id='part2_submission'></a>
# ### Model Selection Implementation Submission
# Implement `SelectorCV`, `SelectorBIC`, and `SelectorDIC` classes in the `my_model_selectors.py` module.  Run the selectors on the following five words. Then answer the questions about your results.
#
# **Tip:** The `hmmlearn` library may not be able to train or score all models.  Implement try/except contructs as necessary to eliminate non-viable models from consideration.

# %%
words_to_train = ['FISH', 'BOOK', 'VEGETABLE', 'FUTURE', 'JOHN']
import timeit
from IPython.core.debugger import Tracer

# %%
# TODO: Implement SelectorCV in my_model_selector.py

from my_model_selectors import SelectorCV

training = asl.build_training(features_ground)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()

# %%
for word in words_to_train:
    start = timeit.default_timer()
#    Tracer()()
    model = SelectorCV(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        print("Training complete for {} with {} states with time {} seconds".format(word, model.n_components, end))
    else:
        print("Training failed for {}".format(word))
# Out:
# failure on FISH with 4 states
# failure on FISH with 5 states
# failure on FISH with 6 states
# failure on FISH with 12 states
# failure on FISH with 13 states
# failure on FISH with 14 states
# failure on FISH with 14 states
# failure on FISH with 15 states
# failure on FISH with 15 states
# The best number of states are 11.0
# Training complete for FISH with 11 states with time 2.1060811442161356 seconds
# The best number of states are 6.0
# Training complete for BOOK with 6 states with time 10.303927930972248 seconds
# failure on VEGETABLE with 13 states
# failure on VEGETABLE with 14 states
# failure on VEGETABLE with 15 states
# The best number of states are 2.0
# Training complete for VEGETABLE with 2 states with time 3.0733554261050546 seconds
# The best number of states are 2.0
# Training complete for FUTURE with 2 states with time 8.4186511974598 seconds
# The best number of states are 12.0
# Training complete for JOHN with 12 states with time 68.51673619191101 seconds

# %%
# TODO: Implement SelectorBIC in module my_model_selectors.py
from my_model_selectors import SelectorBIC

training = asl.build_training(features_ground)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()

# %%
for word in words_to_train:
    start = timeit.default_timer()
    # Tracer()()
    model = SelectorBIC(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        print("Training complete for {} with {} states with time {} seconds".format(word, model.n_components, end))
    else:
        print("Training failed for {}".format(word))
# Out:
# Training complete for FISH with 5 states with time 1.768245629978935 seconds
# Training complete for BOOK with 8 states with time 4.992471476303194 seconds
# Training complete for VEGETABLE with 9 states with time 2.1770237734095588 seconds
# Training complete for FUTURE with 9 states with time 5.643258909961929 seconds
# Training complete for JOHN with 13 states with time 46.19942203807312 seconds

# %%
# TODO: Implement SelectorDIC in module my_model_selectors.py
from my_model_selectors import SelectorDIC

training = asl.build_training(features_ground)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()
for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorDIC(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        print("Training complete for {} with {} states with time {} seconds".format(word, model.n_components, end))
    else:
        print("Training failed for {}".format(word))
# Out:
# Training complete for FISH with 3 states with time 1.2811243334942048 seconds
# Training complete for BOOK with 13 states with time 5.973717366975109 seconds
# Training complete for VEGETABLE with 15 states with time 8.74828192219914 seconds
# Training complete for FUTURE with 15 states with time 6.328665179308558 seconds
# Training complete for JOHN with 15 states with time 42.45777733404498 seconds

# %% [markdown]
# **Question 2:**  Compare and contrast the possible advantages and disadvantages of the various model selectors implemented.
#
# **Answer 2:** BIC tries to penalize complexity. Models using BIC seems to have lesser states as compared to DIC. DIC on the other hand tries to discriminate the word on which the model is being trained on v/s the other words as much as possible. Predicitive accuracy of the model selected using DIC should be higher. Models built and selected using CV should provide similar performance on an unknown data set as compared to the training set on which it was modeled. This is because the model performance in CV is on multiple small test sets from the training sample. The models selected using BIC and DIC can't be expected to have similar performance on an unknown data set as the training set. That's because the model performance in the cases of BIC and DIC are on the training set.

# %% [markdown]
# <a id='part2_test'></a>
# ### Model Selector Unit Testing
# Run the following unit tests as a sanity check on the implemented model selectors.  The test simply looks for valid interfaces  but is not exhaustive. However, the project should not be submitted if these tests don't pass.

# %%
from asl_test_model_selectors import TestSelectors
suite = unittest.TestLoader().loadTestsFromModule(TestSelectors())
unittest.TextTestRunner().run(suite)
# Out:
# ..
# The best number of states are 7.0
# failure on CHICKEN with 3 states
# failure on CHICKEN with 4 states
# failure on CHICKEN with 5 states
# failure on CHICKEN with 6 states
# failure on CHICKEN with 7 states
# .
# failure on CHICKEN with 8 states
# failure on CHICKEN with 9 states
# failure on CHICKEN with 10 states
# The best number of states are 2.0
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 90.389s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>

# %% [markdown]
# <a id='part3_tutorial'></a>
# ## PART 3: Recognizer
# The objective of this section is to "put it all together".  Using the four feature sets created and the three model selectors, you will experiment with the models and present your results.  Instead of training only five specific words as in the previous section, train the entire set with a feature set and model selector strategy.
# ### Recognizer Tutorial
# ##### Train the full training set
# The following example trains the entire set with the example `features_ground` and `SelectorConstant` features and model selector.  Use this pattern for you experimentation and final submission cells.

# %%
# autoreload for automatically reloading changes made in my_model_selectors and my_recognizer
# %load_ext autoreload
# %autoreload 2

from my_model_selectors import SelectorConstant

def train_all_words(features, model_selector):
    training = asl.build_training(features)  # Experiment here with different feature sets defined in part 1
    sequences = training.get_all_sequences()
    Xlengths = training.get_all_Xlengths()
    model_dict = {}
    for word in training.words:
        model = model_selector(sequences, Xlengths, word, 
                        n_constant=3).select()
        model_dict[word]=model
    return model_dict

models = train_all_words(features_ground, SelectorConstant)
print("Number of word models returned = {}".format(len(models)))
# Out:
# Number of word models returned = 112

# %% [markdown]
# ##### Load the test set
# The `build_test` method in `ASLdb` is similar to the `build_training` method already presented, but there are a few differences:
# - the object is type `SinglesData`
# - the internal dictionary keys are the index of the test word rather than the word itself
# - the getter methods are `get_all_sequences`, `get_all_Xlengths`, `get_item_sequences` and `get_item_Xlengths`

# %%
test_set = asl.build_test(features_ground)
print("Number of test set items: {}".format(test_set.num_items))
print("Number of test set sentences: {}".format(len(test_set.sentences_index)))
# Out:
# Number of test set items: 178
# Number of test set sentences: 40

# %% [markdown]
# <a id='part3_submission'></a>
# ### Recognizer Implementation Submission
# For the final project submission, students must implement a recognizer following guidance in the `my_recognizer.py` module.  Experiment with the four feature sets and the three model selection methods (that's 12 possible combinations). You can add and remove cells for experimentation or run the recognizers locally in some other way during your experiments, but retain the results for your discussion.  For submission, you will provide code cells of **only three** interesting combinations for your discussion (see questions below). At least one of these should produce a word error rate of less than 60%, i.e. WER < 0.60 .
#
# **Tip:** The hmmlearn library may not be able to train or score all models.  Implement try/except contructs as necessary to eliminate non-viable models from consideration.

# %%
# TODO implement the recognize method in my_recognizer
from my_recognizer import recognize
from asl_utils import show_errors

# %%
# TODO Choose a feature set and model selector
features = features_ground # change as needed
model_selector = SelectorConstant # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)

# %%
# Tracer()()
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# The model for word having index FIND did not score the word with index 0
# The model for word having index SAY-1P did not score the word with index 0
# The model for word having index LEG did not score the word with index 0
# The model for word having index CANDY did not score the word with index 0
# The model for word having index OLD did not score the word with index 0
# The model for word having index ANN did not score the word with index 0
# The model for word having index FIND did not score the word with index 1
# The model for word having index SAY-1P did not score the word with index 1
# The model for word having index LEG did not score the word with index 1
# The model for word having index CANDY did not score the word with index 1
# The model for word having index OLD did not score the word with index 1
# The model for word having index ANN did not score the word with index 1
# The model for word having index FIND did not score the word with index 2
# The model for word having index SAY-1P did not score the word with index 2
# The model for word having index LEG did not score the word with index 2
# The model for word having index CANDY did not score the word with index 2
# The model for word having index OLD did not score the word with index 2
# The model for word having index ANN did not score the word with index 2
# The model for word having index FIND did not score the word with index 3
# The model for word having index SAY-1P did not score the word with index 3
# The model for word having index LEG did not score the word with index 3
# The model for word having index CANDY did not score the word with index 3
# The model for word having index OLD did not score the word with index 3
# The model for word having index ANN did not score the word with index 3
# The model for word having index FIND did not score the word with index 4
# The model for word having index SAY-1P did not score the word with index 4
# The model for word having index LEG did not score the word with index 4
# The model for word having index CANDY did not score the word with index 4
# The model for word having index OLD did not score the word with index 4
# The model for word having index ANN did not score the word with index 4
# The model for word having index FIND did not score the word with index 5
# The model for word having index SAY-1P did not score the word with index 5
# The model for word having index LEG did not score the word with index 5
# The model for word having index CANDY did not score the word with index 5
# The model for word having index OLD did not score the word with index 5
# The model for word having index ANN did not score the word with index 5
# The model for word having index FIND did not score the word with index 6
# The model for word having index SAY-1P did not score the word with index 6
# The model for word having index LEG did not score the word with index 6
# The model for word having index CANDY did not score the word with index 6
# The model for word having index OLD did not score the word with index 6
# The model for word having index ANN did not score the word with index 6
# The model for word having index FIND did not score the word with index 7
# The model for word having index SAY-1P did not score the word with index 7
# The model for word having index LEG did not score the word with index 7
# The model for word having index CANDY did not score the word with index 7
# The model for word having index OLD did not score the word with index 7
# The model for word having index ANN did not score the word with index 7
# The model for word having index FIND did not score the word with index 8
# The model for word having index SAY-1P did not score the word with index 8
# The model for word having index LEG did not score the word with index 8
# The model for word having index CANDY did not score the word with index 8
# The model for word having index OLD did not score the word with index 8
# The model for word having index ANN did not score the word with index 8
# The model for word having index FIND did not score the word with index 9
# The model for word having index SAY-1P did not score the word with index 9
# The model for word having index LEG did not score the word with index 9
# The model for word having index CANDY did not score the word with index 9
# The model for word having index OLD did not score the word with index 9
# The model for word having index ANN did not score the word with index 9
# The model for word having index FIND did not score the word with index 10
# The model for word having index SAY-1P did not score the word with index 10
# The model for word having index LEG did not score the word with index 10
# The model for word having index CANDY did not score the word with index 10
# The model for word having index OLD did not score the word with index 10
# The model for word having index ANN did not score the word with index 10
# The model for word having index FIND did not score the word with index 11
# The model for word having index SAY-1P did not score the word with index 11
# The model for word having index LEG did not score the word with index 11
# The model for word having index CANDY did not score the word with index 11
# The model for word having index OLD did not score the word with index 11
# The model for word having index ANN did not score the word with index 11
# The model for word having index FIND did not score the word with index 12
# The model for word having index SAY-1P did not score the word with index 12
# The model for word having index LEG did not score the word with index 12
# The model for word having index CANDY did not score the word with index 12
# The model for word having index OLD did not score the word with index 12
# The model for word having index ANN did not score the word with index 12
# The model for word having index FIND did not score the word with index 13
# The model for word having index SAY-1P did not score the word with index 13
# The model for word having index LEG did not score the word with index 13
# The model for word having index CANDY did not score the word with index 13
# The model for word having index OLD did not score the word with index 13
# The model for word having index ANN did not score the word with index 13
# The model for word having index FIND did not score the word with index 14
# The model for word having index SAY-1P did not score the word with index 14
# The model for word having index LEG did not score the word with index 14
# The model for word having index CANDY did not score the word with index 14
# The model for word having index OLD did not score the word with index 14
# The model for word having index ANN did not score the word with index 14
# The model for word having index FIND did not score the word with index 15
# The model for word having index SAY-1P did not score the word with index 15
# The model for word having index LEG did not score the word with index 15
# The model for word having index CANDY did not score the word with index 15
# The model for word having index OLD did not score the word with index 15
# The model for word having index ANN did not score the word with index 15
# The model for word having index FIND did not score the word with index 16
# The model for word having index SAY-1P did not score the word with index 16
# The model for word having index LEG did not score the word with index 16
# The model for word having index CANDY did not score the word with index 16
# The model for word having index OLD did not score the word with index 16
# The model for word having index ANN did not score the word with index 16
# The model for word having index FIND did not score the word with index 17
# The model for word having index SAY-1P did not score the word with index 17
# The model for word having index LEG did not score the word with index 17
# The model for word having index CANDY did not score the word with index 17
# The model for word having index OLD did not score the word with index 17
# The model for word having index ANN did not score the word with index 17
# The model for word having index FIND did not score the word with index 18
# The model for word having index SAY-1P did not score the word with index 18
# The model for word having index LEG did not score the word with index 18
# The model for word having index CANDY did not score the word with index 18
# The model for word having index OLD did not score the word with index 18
# The model for word having index ANN did not score the word with index 18
# The model for word having index FIND did not score the word with index 19
# The model for word having index SAY-1P did not score the word with index 19
# The model for word having index LEG did not score the word with index 19
# The model for word having index CANDY did not score the word with index 19
# The model for word having index OLD did not score the word with index 19
# The model for word having index ANN did not score the word with index 19
# The model for word having index FIND did not score the word with index 20
# The model for word having index SAY-1P did not score the word with index 20
# The model for word having index LEG did not score the word with index 20
# The model for word having index CANDY did not score the word with index 20
# The model for word having index OLD did not score the word with index 20
# The model for word having index ANN did not score the word with index 20
# The model for word having index FIND did not score the word with index 21
# The model for word having index SAY-1P did not score the word with index 21
# The model for word having index LEG did not score the word with index 21
# The model for word having index CANDY did not score the word with index 21
# The model for word having index OLD did not score the word with index 21
# The model for word having index ANN did not score the word with index 21
# The model for word having index FIND did not score the word with index 22
# The model for word having index SAY-1P did not score the word with index 22
# The model for word having index LEG did not score the word with index 22
# The model for word having index CANDY did not score the word with index 22
# The model for word having index OLD did not score the word with index 22
# The model for word having index ANN did not score the word with index 22
# The model for word having index FIND did not score the word with index 23
# The model for word having index SAY-1P did not score the word with index 23
# The model for word having index LEG did not score the word with index 23
# The model for word having index CANDY did not score the word with index 23
# The model for word having index OLD did not score the word with index 23
# The model for word having index ANN did not score the word with index 23
# The model for word having index FIND did not score the word with index 24
# The model for word having index SAY-1P did not score the word with index 24
# The model for word having index LEG did not score the word with index 24
# The model for word having index CANDY did not score the word with index 24
# The model for word having index OLD did not score the word with index 24
# The model for word having index ANN did not score the word with index 24
# The model for word having index FIND did not score the word with index 25
# The model for word having index SAY-1P did not score the word with index 25
# The model for word having index LEG did not score the word with index 25
# The model for word having index CANDY did not score the word with index 25
# The model for word having index OLD did not score the word with index 25
# The model for word having index ANN did not score the word with index 25
# The model for word having index FIND did not score the word with index 26
# The model for word having index SAY-1P did not score the word with index 26
# The model for word having index LEG did not score the word with index 26
# The model for word having index CANDY did not score the word with index 26
# The model for word having index OLD did not score the word with index 26
# The model for word having index ANN did not score the word with index 26
# The model for word having index FIND did not score the word with index 27
# The model for word having index SAY-1P did not score the word with index 27
# The model for word having index LEG did not score the word with index 27
# The model for word having index CANDY did not score the word with index 27
# The model for word having index OLD did not score the word with index 27
# The model for word having index ANN did not score the word with index 27
# The model for word having index FIND did not score the word with index 28
# The model for word having index SAY-1P did not score the word with index 28
# The model for word having index LEG did not score the word with index 28
# The model for word having index CANDY did not score the word with index 28
# The model for word having index OLD did not score the word with index 28
# The model for word having index ANN did not score the word with index 28
# The model for word having index FIND did not score the word with index 29
# The model for word having index SAY-1P did not score the word with index 29
# The model for word having index LEG did not score the word with index 29
# The model for word having index CANDY did not score the word with index 29
# The model for word having index OLD did not score the word with index 29
# The model for word having index ANN did not score the word with index 29
# The model for word having index FIND did not score the word with index 30
# The model for word having index SAY-1P did not score the word with index 30
# The model for word having index LEG did not score the word with index 30
# The model for word having index CANDY did not score the word with index 30
# The model for word having index OLD did not score the word with index 30
# The model for word having index ANN did not score the word with index 30
# The model for word having index FIND did not score the word with index 31
# The model for word having index SAY-1P did not score the word with index 31
# The model for word having index LEG did not score the word with index 31
# The model for word having index CANDY did not score the word with index 31
# The model for word having index OLD did not score the word with index 31
# The model for word having index ANN did not score the word with index 31
# The model for word having index FIND did not score the word with index 32
# The model for word having index SAY-1P did not score the word with index 32
# The model for word having index LEG did not score the word with index 32
# The model for word having index CANDY did not score the word with index 32
# The model for word having index OLD did not score the word with index 32
# The model for word having index ANN did not score the word with index 32
# The model for word having index FIND did not score the word with index 33
# The model for word having index SAY-1P did not score the word with index 33
# The model for word having index LEG did not score the word with index 33
# The model for word having index CANDY did not score the word with index 33
# The model for word having index OLD did not score the word with index 33
# The model for word having index ANN did not score the word with index 33
# The model for word having index FIND did not score the word with index 34
# The model for word having index SAY-1P did not score the word with index 34
# The model for word having index LEG did not score the word with index 34
# The model for word having index CANDY did not score the word with index 34
# The model for word having index OLD did not score the word with index 34
# The model for word having index ANN did not score the word with index 34
# The model for word having index FIND did not score the word with index 35
# The model for word having index SAY-1P did not score the word with index 35
# The model for word having index LEG did not score the word with index 35
# The model for word having index CANDY did not score the word with index 35
# The model for word having index OLD did not score the word with index 35
# The model for word having index ANN did not score the word with index 35
# The model for word having index FIND did not score the word with index 36
# The model for word having index SAY-1P did not score the word with index 36
# The model for word having index LEG did not score the word with index 36
# The model for word having index CANDY did not score the word with index 36
# The model for word having index OLD did not score the word with index 36
# The model for word having index ANN did not score the word with index 36
# The model for word having index FIND did not score the word with index 37
# The model for word having index SAY-1P did not score the word with index 37
# The model for word having index LEG did not score the word with index 37
# The model for word having index CANDY did not score the word with index 37
# The model for word having index OLD did not score the word with index 37
# The model for word having index ANN did not score the word with index 37
# The model for word having index FIND did not score the word with index 38
# The model for word having index SAY-1P did not score the word with index 38
# The model for word having index LEG did not score the word with index 38
# The model for word having index CANDY did not score the word with index 38
# The model for word having index OLD did not score the word with index 38
# The model for word having index ANN did not score the word with index 38
# The model for word having index FIND did not score the word with index 39
# The model for word having index SAY-1P did not score the word with index 39
# The model for word having index LEG did not score the word with index 39
# The model for word having index CANDY did not score the word with index 39
# The model for word having index OLD did not score the word with index 39
# The model for word having index ANN did not score the word with index 39
# The model for word having index FIND did not score the word with index 40
# The model for word having index SAY-1P did not score the word with index 40
# The model for word having index LEG did not score the word with index 40
# The model for word having index CANDY did not score the word with index 40
# The model for word having index OLD did not score the word with index 40
# The model for word having index ANN did not score the word with index 40
# The model for word having index FIND did not score the word with index 41
# The model for word having index SAY-1P did not score the word with index 41
# The model for word having index LEG did not score the word with index 41
# The model for word having index CANDY did not score the word with index 41
# The model for word having index OLD did not score the word with index 41
# The model for word having index ANN did not score the word with index 41
# The model for word having index FIND did not score the word with index 42
# The model for word having index SAY-1P did not score the word with index 42
# The model for word having index LEG did not score the word with index 42
# The model for word having index CANDY did not score the word with index 42
# The model for word having index OLD did not score the word with index 42
# The model for word having index ANN did not score the word with index 42
# The model for word having index FIND did not score the word with index 43
# The model for word having index SAY-1P did not score the word with index 43
# The model for word having index LEG did not score the word with index 43
# The model for word having index CANDY did not score the word with index 43
# The model for word having index OLD did not score the word with index 43
# The model for word having index ANN did not score the word with index 43
# The model for word having index FIND did not score the word with index 44
# The model for word having index SAY-1P did not score the word with index 44
# The model for word having index LEG did not score the word with index 44
# The model for word having index CANDY did not score the word with index 44
# The model for word having index OLD did not score the word with index 44
# The model for word having index ANN did not score the word with index 44
# The model for word having index FIND did not score the word with index 45
# The model for word having index SAY-1P did not score the word with index 45
# The model for word having index LEG did not score the word with index 45
# The model for word having index CANDY did not score the word with index 45
# The model for word having index OLD did not score the word with index 45
# The model for word having index ANN did not score the word with index 45
# The model for word having index FIND did not score the word with index 46
# The model for word having index SAY-1P did not score the word with index 46
# The model for word having index LEG did not score the word with index 46
# The model for word having index CANDY did not score the word with index 46
# The model for word having index OLD did not score the word with index 46
# The model for word having index ANN did not score the word with index 46
# The model for word having index FIND did not score the word with index 47
# The model for word having index SAY-1P did not score the word with index 47
# The model for word having index LEG did not score the word with index 47
# The model for word having index CANDY did not score the word with index 47
# The model for word having index OLD did not score the word with index 47
# The model for word having index ANN did not score the word with index 47
# The model for word having index FIND did not score the word with index 48
# The model for word having index SAY-1P did not score the word with index 48
# The model for word having index LEG did not score the word with index 48
# The model for word having index CANDY did not score the word with index 48
# The model for word having index OLD did not score the word with index 48
# The model for word having index ANN did not score the word with index 48
# The model for word having index FIND did not score the word with index 49
# The model for word having index SAY-1P did not score the word with index 49
# The model for word having index LEG did not score the word with index 49
# The model for word having index CANDY did not score the word with index 49
# The model for word having index OLD did not score the word with index 49
# The model for word having index ANN did not score the word with index 49
# The model for word having index FIND did not score the word with index 50
# The model for word having index SAY-1P did not score the word with index 50
# The model for word having index LEG did not score the word with index 50
# The model for word having index CANDY did not score the word with index 50
# The model for word having index OLD did not score the word with index 50
# The model for word having index ANN did not score the word with index 50
# The model for word having index FIND did not score the word with index 51
# The model for word having index SAY-1P did not score the word with index 51
# The model for word having index LEG did not score the word with index 51
# The model for word having index CANDY did not score the word with index 51
# The model for word having index OLD did not score the word with index 51
# The model for word having index ANN did not score the word with index 51
# The model for word having index FIND did not score the word with index 52
# The model for word having index SAY-1P did not score the word with index 52
# The model for word having index LEG did not score the word with index 52
# The model for word having index CANDY did not score the word with index 52
# The model for word having index OLD did not score the word with index 52
# The model for word having index ANN did not score the word with index 52
# The model for word having index FIND did not score the word with index 53
# The model for word having index SAY-1P did not score the word with index 53
# The model for word having index LEG did not score the word with index 53
# The model for word having index CANDY did not score the word with index 53
# The model for word having index OLD did not score the word with index 53
# The model for word having index ANN did not score the word with index 53
# The model for word having index FIND did not score the word with index 54
# The model for word having index SAY-1P did not score the word with index 54
# The model for word having index LEG did not score the word with index 54
# The model for word having index CANDY did not score the word with index 54
# The model for word having index OLD did not score the word with index 54
# The model for word having index ANN did not score the word with index 54
# The model for word having index FIND did not score the word with index 55
# The model for word having index SAY-1P did not score the word with index 55
# The model for word having index LEG did not score the word with index 55
# The model for word having index CANDY did not score the word with index 55
# The model for word having index OLD did not score the word with index 55
# The model for word having index ANN did not score the word with index 55
# The model for word having index FIND did not score the word with index 56
# The model for word having index SAY-1P did not score the word with index 56
# The model for word having index LEG did not score the word with index 56
# The model for word having index CANDY did not score the word with index 56
# The model for word having index OLD did not score the word with index 56
# The model for word having index ANN did not score the word with index 56
# The model for word having index FIND did not score the word with index 57
# The model for word having index SAY-1P did not score the word with index 57
# The model for word having index LEG did not score the word with index 57
# The model for word having index CANDY did not score the word with index 57
# The model for word having index OLD did not score the word with index 57
# The model for word having index ANN did not score the word with index 57
# The model for word having index FIND did not score the word with index 58
# The model for word having index SAY-1P did not score the word with index 58
# The model for word having index LEG did not score the word with index 58
# The model for word having index CANDY did not score the word with index 58
# The model for word having index OLD did not score the word with index 58
# The model for word having index ANN did not score the word with index 58
# The model for word having index FIND did not score the word with index 59
# The model for word having index SAY-1P did not score the word with index 59
# The model for word having index LEG did not score the word with index 59
# The model for word having index CANDY did not score the word with index 59
# The model for word having index OLD did not score the word with index 59
# The model for word having index ANN did not score the word with index 59
# The model for word having index FIND did not score the word with index 60
# The model for word having index SAY-1P did not score the word with index 60
# The model for word having index LEG did not score the word with index 60
# The model for word having index CANDY did not score the word with index 60
# The model for word having index OLD did not score the word with index 60
# The model for word having index ANN did not score the word with index 60
# The model for word having index FIND did not score the word with index 61
# The model for word having index SAY-1P did not score the word with index 61
# The model for word having index LEG did not score the word with index 61
# The model for word having index CANDY did not score the word with index 61
# The model for word having index OLD did not score the word with index 61
# The model for word having index ANN did not score the word with index 61
# The model for word having index FIND did not score the word with index 62
# The model for word having index SAY-1P did not score the word with index 62
# The model for word having index LEG did not score the word with index 62
# The model for word having index CANDY did not score the word with index 62
# The model for word having index OLD did not score the word with index 62
# The model for word having index ANN did not score the word with index 62
# The model for word having index FIND did not score the word with index 63
# The model for word having index SAY-1P did not score the word with index 63
# The model for word having index LEG did not score the word with index 63
# The model for word having index CANDY did not score the word with index 63
# The model for word having index OLD did not score the word with index 63
# The model for word having index ANN did not score the word with index 63
# The model for word having index FIND did not score the word with index 64
# The model for word having index SAY-1P did not score the word with index 64
# The model for word having index LEG did not score the word with index 64
# The model for word having index CANDY did not score the word with index 64
# The model for word having index OLD did not score the word with index 64
# The model for word having index ANN did not score the word with index 64
# The model for word having index FIND did not score the word with index 65
# The model for word having index SAY-1P did not score the word with index 65
# The model for word having index LEG did not score the word with index 65
# The model for word having index CANDY did not score the word with index 65
# The model for word having index OLD did not score the word with index 65
# The model for word having index ANN did not score the word with index 65
# The model for word having index FIND did not score the word with index 66
# The model for word having index SAY-1P did not score the word with index 66
# The model for word having index LEG did not score the word with index 66
# The model for word having index CANDY did not score the word with index 66
# The model for word having index OLD did not score the word with index 66
# The model for word having index ANN did not score the word with index 66
# The model for word having index FIND did not score the word with index 67
# The model for word having index SAY-1P did not score the word with index 67
# The model for word having index LEG did not score the word with index 67
# The model for word having index CANDY did not score the word with index 67
# The model for word having index OLD did not score the word with index 67
# The model for word having index ANN did not score the word with index 67
# The model for word having index FIND did not score the word with index 68
# The model for word having index SAY-1P did not score the word with index 68
# The model for word having index LEG did not score the word with index 68
# The model for word having index CANDY did not score the word with index 68
# The model for word having index OLD did not score the word with index 68
# The model for word having index ANN did not score the word with index 68
# The model for word having index FIND did not score the word with index 69
# The model for word having index SAY-1P did not score the word with index 69
# The model for word having index LEG did not score the word with index 69
# The model for word having index CANDY did not score the word with index 69
# The model for word having index OLD did not score the word with index 69
# The model for word having index ANN did not score the word with index 69
# The model for word having index FIND did not score the word with index 70
# The model for word having index SAY-1P did not score the word with index 70
# The model for word having index LEG did not score the word with index 70
# The model for word having index CANDY did not score the word with index 70
# The model for word having index OLD did not score the word with index 70
# The model for word having index ANN did not score the word with index 70
# The model for word having index FIND did not score the word with index 71
# The model for word having index SAY-1P did not score the word with index 71
# The model for word having index LEG did not score the word with index 71
# The model for word having index CANDY did not score the word with index 71
# The model for word having index OLD did not score the word with index 71
# The model for word having index ANN did not score the word with index 71
# The model for word having index FIND did not score the word with index 72
# The model for word having index SAY-1P did not score the word with index 72
# The model for word having index LEG did not score the word with index 72
# The model for word having index CANDY did not score the word with index 72
# The model for word having index OLD did not score the word with index 72
# The model for word having index ANN did not score the word with index 72
# The model for word having index FIND did not score the word with index 73
# The model for word having index SAY-1P did not score the word with index 73
# The model for word having index LEG did not score the word with index 73
# The model for word having index CANDY did not score the word with index 73
# The model for word having index OLD did not score the word with index 73
# The model for word having index ANN did not score the word with index 73
# The model for word having index FIND did not score the word with index 74
# The model for word having index SAY-1P did not score the word with index 74
# The model for word having index LEG did not score the word with index 74
# The model for word having index CANDY did not score the word with index 74
# The model for word having index OLD did not score the word with index 74
# The model for word having index ANN did not score the word with index 74
# The model for word having index FIND did not score the word with index 75
# The model for word having index SAY-1P did not score the word with index 75
# The model for word having index LEG did not score the word with index 75
# The model for word having index CANDY did not score the word with index 75
# The model for word having index OLD did not score the word with index 75
# The model for word having index ANN did not score the word with index 75
# The model for word having index FIND did not score the word with index 76
# The model for word having index SAY-1P did not score the word with index 76
# The model for word having index LEG did not score the word with index 76
# The model for word having index CANDY did not score the word with index 76
# The model for word having index OLD did not score the word with index 76
# The model for word having index ANN did not score the word with index 76
# The model for word having index FIND did not score the word with index 77
# The model for word having index SAY-1P did not score the word with index 77
# The model for word having index LEG did not score the word with index 77
# The model for word having index CANDY did not score the word with index 77
# The model for word having index OLD did not score the word with index 77
# The model for word having index ANN did not score the word with index 77
# The model for word having index FIND did not score the word with index 78
# The model for word having index SAY-1P did not score the word with index 78
# The model for word having index LEG did not score the word with index 78
# The model for word having index CANDY did not score the word with index 78
# The model for word having index OLD did not score the word with index 78
# The model for word having index ANN did not score the word with index 78
# The model for word having index FIND did not score the word with index 79
# The model for word having index SAY-1P did not score the word with index 79
# The model for word having index LEG did not score the word with index 79
# The model for word having index CANDY did not score the word with index 79
# The model for word having index OLD did not score the word with index 79
# The model for word having index ANN did not score the word with index 79
# The model for word having index FIND did not score the word with index 80
# The model for word having index SAY-1P did not score the word with index 80
# The model for word having index LEG did not score the word with index 80
# The model for word having index CANDY did not score the word with index 80
# The model for word having index OLD did not score the word with index 80
# The model for word having index ANN did not score the word with index 80
# The model for word having index FIND did not score the word with index 81
# The model for word having index SAY-1P did not score the word with index 81
# The model for word having index LEG did not score the word with index 81
# The model for word having index CANDY did not score the word with index 81
# The model for word having index OLD did not score the word with index 81
# The model for word having index ANN did not score the word with index 81
# The model for word having index FIND did not score the word with index 82
# The model for word having index SAY-1P did not score the word with index 82
# The model for word having index LEG did not score the word with index 82
# The model for word having index CANDY did not score the word with index 82
# The model for word having index OLD did not score the word with index 82
# The model for word having index ANN did not score the word with index 82
# The model for word having index FIND did not score the word with index 83
# The model for word having index SAY-1P did not score the word with index 83
# The model for word having index LEG did not score the word with index 83
# The model for word having index CANDY did not score the word with index 83
# The model for word having index OLD did not score the word with index 83
# The model for word having index ANN did not score the word with index 83
# The model for word having index FIND did not score the word with index 84
# The model for word having index SAY-1P did not score the word with index 84
# The model for word having index LEG did not score the word with index 84
# The model for word having index CANDY did not score the word with index 84
# The model for word having index OLD did not score the word with index 84
# The model for word having index ANN did not score the word with index 84
# The model for word having index FIND did not score the word with index 85
# The model for word having index SAY-1P did not score the word with index 85
# The model for word having index LEG did not score the word with index 85
# The model for word having index CANDY did not score the word with index 85
# The model for word having index OLD did not score the word with index 85
# The model for word having index ANN did not score the word with index 85
# The model for word having index FIND did not score the word with index 86
# The model for word having index SAY-1P did not score the word with index 86
# The model for word having index LEG did not score the word with index 86
# The model for word having index CANDY did not score the word with index 86
# The model for word having index OLD did not score the word with index 86
# The model for word having index ANN did not score the word with index 86
# The model for word having index FIND did not score the word with index 87
# The model for word having index SAY-1P did not score the word with index 87
# The model for word having index LEG did not score the word with index 87
# The model for word having index CANDY did not score the word with index 87
# The model for word having index OLD did not score the word with index 87
# The model for word having index ANN did not score the word with index 87
# The model for word having index FIND did not score the word with index 88
# The model for word having index SAY-1P did not score the word with index 88
# The model for word having index LEG did not score the word with index 88
# The model for word having index CANDY did not score the word with index 88
# The model for word having index OLD did not score the word with index 88
# The model for word having index ANN did not score the word with index 88
# The model for word having index FIND did not score the word with index 89
# The model for word having index SAY-1P did not score the word with index 89
# The model for word having index LEG did not score the word with index 89
# The model for word having index CANDY did not score the word with index 89
# The model for word having index OLD did not score the word with index 89
# The model for word having index ANN did not score the word with index 89
# The model for word having index FIND did not score the word with index 90
# The model for word having index SAY-1P did not score the word with index 90
# The model for word having index LEG did not score the word with index 90
# The model for word having index CANDY did not score the word with index 90
# The model for word having index OLD did not score the word with index 90
# The model for word having index ANN did not score the word with index 90
# The model for word having index FIND did not score the word with index 91
# The model for word having index SAY-1P did not score the word with index 91
# The model for word having index LEG did not score the word with index 91
# The model for word having index CANDY did not score the word with index 91
# The model for word having index OLD did not score the word with index 91
# The model for word having index ANN did not score the word with index 91
# The model for word having index FIND did not score the word with index 92
# The model for word having index SAY-1P did not score the word with index 92
# The model for word having index LEG did not score the word with index 92
# The model for word having index CANDY did not score the word with index 92
# The model for word having index OLD did not score the word with index 92
# The model for word having index ANN did not score the word with index 92
# The model for word having index FIND did not score the word with index 93
# The model for word having index SAY-1P did not score the word with index 93
# The model for word having index LEG did not score the word with index 93
# The model for word having index CANDY did not score the word with index 93
# The model for word having index OLD did not score the word with index 93
# The model for word having index ANN did not score the word with index 93
# The model for word having index FIND did not score the word with index 94
# The model for word having index SAY-1P did not score the word with index 94
# The model for word having index LEG did not score the word with index 94
# The model for word having index CANDY did not score the word with index 94
# The model for word having index OLD did not score the word with index 94
# The model for word having index ANN did not score the word with index 94
# The model for word having index FIND did not score the word with index 95
# The model for word having index SAY-1P did not score the word with index 95
# The model for word having index LEG did not score the word with index 95
# The model for word having index CANDY did not score the word with index 95
# The model for word having index OLD did not score the word with index 95
# The model for word having index ANN did not score the word with index 95
# The model for word having index FIND did not score the word with index 96
# The model for word having index SAY-1P did not score the word with index 96
# The model for word having index LEG did not score the word with index 96
# The model for word having index CANDY did not score the word with index 96
# The model for word having index OLD did not score the word with index 96
# The model for word having index ANN did not score the word with index 96
# The model for word having index FIND did not score the word with index 97
# The model for word having index SAY-1P did not score the word with index 97
# The model for word having index LEG did not score the word with index 97
# The model for word having index CANDY did not score the word with index 97
# The model for word having index OLD did not score the word with index 97
# The model for word having index ANN did not score the word with index 97
# The model for word having index FIND did not score the word with index 98
# The model for word having index SAY-1P did not score the word with index 98
# The model for word having index LEG did not score the word with index 98
# The model for word having index CANDY did not score the word with index 98
# The model for word having index OLD did not score the word with index 98
# The model for word having index ANN did not score the word with index 98
# The model for word having index FIND did not score the word with index 99
# The model for word having index SAY-1P did not score the word with index 99
# The model for word having index LEG did not score the word with index 99
# The model for word having index CANDY did not score the word with index 99
# The model for word having index OLD did not score the word with index 99
# The model for word having index ANN did not score the word with index 99
# The model for word having index FIND did not score the word with index 100
# The model for word having index SAY-1P did not score the word with index 100
# The model for word having index LEG did not score the word with index 100
# The model for word having index CANDY did not score the word with index 100
# The model for word having index OLD did not score the word with index 100
# The model for word having index ANN did not score the word with index 100
# The model for word having index FIND did not score the word with index 101
# The model for word having index SAY-1P did not score the word with index 101
# The model for word having index LEG did not score the word with index 101
# The model for word having index CANDY did not score the word with index 101
# The model for word having index OLD did not score the word with index 101
# The model for word having index ANN did not score the word with index 101
# The model for word having index FIND did not score the word with index 102
# The model for word having index SAY-1P did not score the word with index 102
# The model for word having index LEG did not score the word with index 102
# The model for word having index CANDY did not score the word with index 102
# The model for word having index OLD did not score the word with index 102
# The model for word having index ANN did not score the word with index 102
# The model for word having index FIND did not score the word with index 103
# The model for word having index SAY-1P did not score the word with index 103
# The model for word having index LEG did not score the word with index 103
# The model for word having index CANDY did not score the word with index 103
# The model for word having index OLD did not score the word with index 103
# The model for word having index ANN did not score the word with index 103
# The model for word having index FIND did not score the word with index 104
# The model for word having index SAY-1P did not score the word with index 104
# The model for word having index LEG did not score the word with index 104
# The model for word having index CANDY did not score the word with index 104
# The model for word having index OLD did not score the word with index 104
# The model for word having index ANN did not score the word with index 104
# The model for word having index FIND did not score the word with index 105
# The model for word having index SAY-1P did not score the word with index 105
# The model for word having index LEG did not score the word with index 105
# The model for word having index CANDY did not score the word with index 105
# The model for word having index OLD did not score the word with index 105
# The model for word having index ANN did not score the word with index 105
# The model for word having index FIND did not score the word with index 106
# The model for word having index SAY-1P did not score the word with index 106
# The model for word having index LEG did not score the word with index 106
# The model for word having index CANDY did not score the word with index 106
# The model for word having index OLD did not score the word with index 106
# The model for word having index ANN did not score the word with index 106
# The model for word having index FIND did not score the word with index 107
# The model for word having index SAY-1P did not score the word with index 107
# The model for word having index LEG did not score the word with index 107
# The model for word having index CANDY did not score the word with index 107
# The model for word having index OLD did not score the word with index 107
# The model for word having index ANN did not score the word with index 107
# ...
# The model for word having index SAY-1P did not score the word with index 151
# The model for word having index LEG did not score the word with index 151
# The model for word having index CANDY did not score the word with index 151
# The model for word having index OLD did not score the word with index 151
# The model for word having index ANN did not score the word with index 151
# The model for word having index FIND did not score the word with index 152
# The model for word having index SAY-1P did not score the word with index 152
# The model for word having index LEG did not score the word with index 152
# The model for word having index CANDY did not score the word with index 152
# The model for word having index OLD did not score the word with index 152
# The model for word having index ANN did not score the word with index 152
# The model for word having index FIND did not score the word with index 153
# The model for word having index SAY-1P did not score the word with index 153
# The model for word having index LEG did not score the word with index 153
# The model for word having index CANDY did not score the word with index 153
# The model for word having index OLD did not score the word with index 153
# The model for word having index ANN did not score the word with index 153
# The model for word having index FIND did not score the word with index 154
# The model for word having index SAY-1P did not score the word with index 154
# The model for word having index LEG did not score the word with index 154
# The model for word having index CANDY did not score the word with index 154
# The model for word having index OLD did not score the word with index 154
# The model for word having index ANN did not score the word with index 154
# The model for word having index FIND did not score the word with index 155
# The model for word having index SAY-1P did not score the word with index 155
# The model for word having index LEG did not score the word with index 155
# The model for word having index CANDY did not score the word with index 155
# The model for word having index OLD did not score the word with index 155
# The model for word having index ANN did not score the word with index 155
# The model for word having index FIND did not score the word with index 156
# The model for word having index SAY-1P did not score the word with index 156
# The model for word having index LEG did not score the word with index 156
# The model for word having index CANDY did not score the word with index 156
# The model for word having index OLD did not score the word with index 156
# The model for word having index ANN did not score the word with index 156
# The model for word having index FIND did not score the word with index 157
# The model for word having index SAY-1P did not score the word with index 157
# The model for word having index LEG did not score the word with index 157
# The model for word having index CANDY did not score the word with index 157
# The model for word having index OLD did not score the word with index 157
# The model for word having index ANN did not score the word with index 157
# The model for word having index FIND did not score the word with index 158
# The model for word having index SAY-1P did not score the word with index 158
# The model for word having index LEG did not score the word with index 158
# The model for word having index CANDY did not score the word with index 158
# The model for word having index OLD did not score the word with index 158
# The model for word having index ANN did not score the word with index 158
# The model for word having index FIND did not score the word with index 159
# The model for word having index SAY-1P did not score the word with index 159
# The model for word having index LEG did not score the word with index 159
# The model for word having index CANDY did not score the word with index 159
# The model for word having index OLD did not score the word with index 159
# The model for word having index ANN did not score the word with index 159
# The model for word having index FIND did not score the word with index 160
# The model for word having index SAY-1P did not score the word with index 160
# The model for word having index LEG did not score the word with index 160
# The model for word having index CANDY did not score the word with index 160
# The model for word having index OLD did not score the word with index 160
# The model for word having index ANN did not score the word with index 160
# The model for word having index FIND did not score the word with index 161
# The model for word having index SAY-1P did not score the word with index 161
# The model for word having index LEG did not score the word with index 161
# The model for word having index CANDY did not score the word with index 161
# The model for word having index OLD did not score the word with index 161
# The model for word having index ANN did not score the word with index 161
# The model for word having index FIND did not score the word with index 162
# The model for word having index SAY-1P did not score the word with index 162
# The model for word having index LEG did not score the word with index 162
# The model for word having index CANDY did not score the word with index 162
# The model for word having index OLD did not score the word with index 162
# The model for word having index ANN did not score the word with index 162
# The model for word having index FIND did not score the word with index 163
# The model for word having index SAY-1P did not score the word with index 163
# The model for word having index LEG did not score the word with index 163
# The model for word having index CANDY did not score the word with index 163
# The model for word having index OLD did not score the word with index 163
# The model for word having index ANN did not score the word with index 163
# The model for word having index FIND did not score the word with index 164
# The model for word having index SAY-1P did not score the word with index 164
# The model for word having index LEG did not score the word with index 164
# The model for word having index CANDY did not score the word with index 164
# The model for word having index OLD did not score the word with index 164
# The model for word having index ANN did not score the word with index 164
# The model for word having index FIND did not score the word with index 165
# The model for word having index SAY-1P did not score the word with index 165
# The model for word having index LEG did not score the word with index 165
# The model for word having index CANDY did not score the word with index 165
# The model for word having index OLD did not score the word with index 165
# The model for word having index ANN did not score the word with index 165
# The model for word having index FIND did not score the word with index 166
# The model for word having index SAY-1P did not score the word with index 166
# The model for word having index LEG did not score the word with index 166
# The model for word having index CANDY did not score the word with index 166
# The model for word having index OLD did not score the word with index 166
# The model for word having index ANN did not score the word with index 166
# The model for word having index FIND did not score the word with index 167
# The model for word having index SAY-1P did not score the word with index 167
# The model for word having index LEG did not score the word with index 167
# The model for word having index CANDY did not score the word with index 167
# The model for word having index OLD did not score the word with index 167
# The model for word having index ANN did not score the word with index 167
# The model for word having index FIND did not score the word with index 168
# The model for word having index SAY-1P did not score the word with index 168
# The model for word having index LEG did not score the word with index 168
# The model for word having index CANDY did not score the word with index 168
# The model for word having index OLD did not score the word with index 168
# The model for word having index ANN did not score the word with index 168
# The model for word having index FIND did not score the word with index 169
# The model for word having index SAY-1P did not score the word with index 169
# The model for word having index LEG did not score the word with index 169
# The model for word having index CANDY did not score the word with index 169
# The model for word having index OLD did not score the word with index 169
# The model for word having index ANN did not score the word with index 169
# The model for word having index FIND did not score the word with index 170
# The model for word having index SAY-1P did not score the word with index 170
# The model for word having index LEG did not score the word with index 170
# The model for word having index CANDY did not score the word with index 170
# The model for word having index OLD did not score the word with index 170
# The model for word having index ANN did not score the word with index 170
# The model for word having index FIND did not score the word with index 171
# The model for word having index SAY-1P did not score the word with index 171
# The model for word having index LEG did not score the word with index 171
# The model for word having index CANDY did not score the word with index 171
# The model for word having index OLD did not score the word with index 171
# The model for word having index ANN did not score the word with index 171
# The model for word having index FIND did not score the word with index 172
# The model for word having index SAY-1P did not score the word with index 172
# The model for word having index LEG did not score the word with index 172
# The model for word having index CANDY did not score the word with index 172
# The model for word having index OLD did not score the word with index 172
# The model for word having index ANN did not score the word with index 172
# The model for word having index FIND did not score the word with index 173
# The model for word having index SAY-1P did not score the word with index 173
# The model for word having index LEG did not score the word with index 173
# The model for word having index CANDY did not score the word with index 173
# The model for word having index OLD did not score the word with index 173
# The model for word having index ANN did not score the word with index 173
# The model for word having index FIND did not score the word with index 174
# The model for word having index SAY-1P did not score the word with index 174
# The model for word having index LEG did not score the word with index 174
# The model for word having index CANDY did not score the word with index 174
# The model for word having index OLD did not score the word with index 174
# The model for word having index ANN did not score the word with index 174
# The model for word having index FIND did not score the word with index 175
# The model for word having index SAY-1P did not score the word with index 175
# The model for word having index LEG did not score the word with index 175
# The model for word having index CANDY did not score the word with index 175
# The model for word having index OLD did not score the word with index 175
# The model for word having index ANN did not score the word with index 175
# The model for word having index FIND did not score the word with index 176
# The model for word having index SAY-1P did not score the word with index 176
# The model for word having index LEG did not score the word with index 176
# The model for word having index CANDY did not score the word with index 176
# The model for word having index OLD did not score the word with index 176
# The model for word having index ANN did not score the word with index 176
# The model for word having index FIND did not score the word with index 177
# The model for word having index SAY-1P did not score the word with index 177
# The model for word having index LEG did not score the word with index 177
# The model for word having index CANDY did not score the word with index 177
# The model for word having index OLD did not score the word with index 177
# The model for word having index ANN did not score the word with index 177
#
# **** WER = 0.6685393258426966
# Total correct: 59 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#     2: *GO WRITE *ARRIVE                                             JOHN WRITE HOMEWORK
#    67: *LIKE FUTURE NOT BUY HOUSE                                    JOHN FUTURE NOT BUY HOUSE
#     7: *SOMETHING-ONE *GO1 *IX CAN                                   JOHN CAN GO CAN
#   201: JOHN *GIVE *GIVE *LOVE *ARRIVE HOUSE                          JOHN TELL MARY IX-1P BUY HOUSE
#    74: *IX *VISIT *GO *GO                                            JOHN NOT VISIT MARY
#   119: *PREFER *BUY1 IX *BLAME *IX                                   SUE BUY IX CAR BLUE
#    12: JOHN *HAVE *WHAT CAN                                          JOHN CAN GO CAN
#    77: *JOHN BLAME *LOVE                                             ANN BLAME MARY
#   142: *FRANK *STUDENT YESTERDAY *TEACHER BOOK                       JOHN BUY YESTERDAY WHAT BOOK
#   107: *SHOULD *IX FRIEND *GO *JANA                                  JOHN POSS FRIEND HAVE CANDY
#    84: *LOVE *ARRIVE *HOMEWORK BOOK                                  IX-1P FIND SOMETHING-ONE BOOK
#    21: JOHN *HOMEWORK *NEW *PREFER *CAR *CAR *FUTURE *EAT            JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: *FRANK *TELL *LOVE *TELL *LOVE                                JOHN LIKE IX IX IX
#    89: *GIVE *GIVE GIVE *IX IX *ARRIVE *BOOK                         JOHN IX GIVE MAN IX NEW COAT
#    71: JOHN *FINISH VISIT MARY                                       JOHN WILL VISIT MARY
#    92: *FRANK GIVE *WOMAN *WOMAN WOMAN BOOK                          JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    90: *SOMETHING-ONE *SOMETHING-ONE IX *IX WOMAN *COAT              JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    30: *SHOULD LIKE *GO *GO *GO                                      JOHN LIKE IX IX IX
#   193: JOHN *SOMETHING-ONE *YESTERDAY BOX                            JOHN GIVE GIRL BOX
#    36: *VISIT VEGETABLE *YESTERDAY *GIVE *MARY *MARY                 MARY VEGETABLE KNOW IX LIKE CORN1
#   139: *SHOULD *BUY1 *CAR *BLAME BOOK                                JOHN BUY WHAT YESTERDAY BOOK
#   167: *MARY IX *VISIT *WOMAN *LOVE                                  JOHN IX SAY LOVE MARY
#    40: *SUE *GIVE *CORN *VEGETABLE *GO                               JOHN IX THINK MARY LOVE
#    28: *FRANK *TELL *LOVE *TELL *LOVE                                JOHN LIKE IX IX IX
#   171: *VISIT *VISIT BLAME                                           JOHN MARY BLAME
#    43: *FRANK *GO BUY HOUSE                                          JOHN MUST BUY HOUSE
#   108: *GIVE *LOVE                                                   WOMAN ARRIVE
#   174: *CAN *GIVE3 GIVE1 *APPLE *WHAT                                PEOPLE GROUP GIVE1 JANA TOY
#   113: IX CAR *CAR *IX *IX                                           IX CAR BLUE SUE BUY
#    50: *FRANK *SEE BUY CAR *SOMETHING-ONE                            FUTURE JOHN BUY CAR SHOULD
#   199: *LOVE CHOCOLATE WHO                                           LIKE CHOCOLATE WHO
#   158: LOVE *MARY WHO                                                LOVE JOHN WHO
#    54: JOHN SHOULD *WHO BUY HOUSE                                    JOHN SHOULD NOT BUY HOUSE
#   105: *FRANK *VEGETABLE                                             JOHN LEG
#   184: *GIVE1 BOY *GIVE1 TEACHER APPLE                               ALL BOY GIVE TEACHER APPLE
#    57: *MARY *VISIT VISIT *VISIT                                     JOHN DECIDE VISIT MARY
#   122: JOHN *GIVE1 *COAT                                             JOHN READ BOOK
#   189: *JANA *SOMETHING-ONE *YESTERDAY *WHAT                         JOHN GIVE GIRL BOX
#   181: *BLAME ARRIVE                                                 JOHN ARRIVE

# %%
from my_model_selectors import SelectorDIC

# TODO Choose a feature set and model selector
features = features_ground # change as needed
model_selector = SelectorDIC # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# The model for word having index SAY-1P did not score the word with index 0
# The model for word having index LEG did not score the word with index 0
# The model for word having index SAY-1P did not score the word with index 1
# The model for word having index LEG did not score the word with index 1
# The model for word having index SAY-1P did not score the word with index 2
# The model for word having index LEG did not score the word with index 2
# The model for word having index SAY-1P did not score the word with index 3
# The model for word having index LEG did not score the word with index 3
# The model for word having index SAY-1P did not score the word with index 4
# The model for word having index LEG did not score the word with index 4
# The model for word having index SAY-1P did not score the word with index 5
# The model for word having index LEG did not score the word with index 5
# The model for word having index SAY-1P did not score the word with index 6
# The model for word having index LEG did not score the word with index 6
# The model for word having index SAY-1P did not score the word with index 7
# The model for word having index LEG did not score the word with index 7
# The model for word having index SAY-1P did not score the word with index 8
# The model for word having index LEG did not score the word with index 8
# The model for word having index SAY-1P did not score the word with index 9
# The model for word having index LEG did not score the word with index 9
# The model for word having index SAY-1P did not score the word with index 10
# The model for word having index LEG did not score the word with index 10
# The model for word having index SAY-1P did not score the word with index 11
# The model for word having index LEG did not score the word with index 11
# The model for word having index SAY-1P did not score the word with index 12
# The model for word having index LEG did not score the word with index 12
# The model for word having index SAY-1P did not score the word with index 13
# The model for word having index LEG did not score the word with index 13
# The model for word having index SAY-1P did not score the word with index 14
# The model for word having index LEG did not score the word with index 14
# The model for word having index SAY-1P did not score the word with index 15
# The model for word having index LEG did not score the word with index 15
# The model for word having index SAY-1P did not score the word with index 16
# The model for word having index LEG did not score the word with index 16
# The model for word having index SAY-1P did not score the word with index 17
# The model for word having index LEG did not score the word with index 17
# The model for word having index SAY-1P did not score the word with index 18
# The model for word having index LEG did not score the word with index 18
# The model for word having index SAY-1P did not score the word with index 19
# The model for word having index LEG did not score the word with index 19
# The model for word having index SAY-1P did not score the word with index 20
# The model for word having index LEG did not score the word with index 20
# The model for word having index SAY-1P did not score the word with index 21
# The model for word having index LEG did not score the word with index 21
# The model for word having index SAY-1P did not score the word with index 22
# The model for word having index LEG did not score the word with index 22
# The model for word having index SAY-1P did not score the word with index 23
# The model for word having index LEG did not score the word with index 23
# The model for word having index SAY-1P did not score the word with index 24
# The model for word having index LEG did not score the word with index 24
# The model for word having index SAY-1P did not score the word with index 25
# The model for word having index LEG did not score the word with index 25
# The model for word having index SAY-1P did not score the word with index 26
# The model for word having index LEG did not score the word with index 26
# The model for word having index SAY-1P did not score the word with index 27
# The model for word having index LEG did not score the word with index 27
# The model for word having index SAY-1P did not score the word with index 28
# The model for word having index LEG did not score the word with index 28
# The model for word having index SAY-1P did not score the word with index 29
# The model for word having index LEG did not score the word with index 29
# The model for word having index SAY-1P did not score the word with index 30
# The model for word having index LEG did not score the word with index 30
# The model for word having index SAY-1P did not score the word with index 31
# The model for word having index LEG did not score the word with index 31
# The model for word having index SAY-1P did not score the word with index 32
# The model for word having index LEG did not score the word with index 32
# The model for word having index SAY-1P did not score the word with index 33
# The model for word having index LEG did not score the word with index 33
# The model for word having index SAY-1P did not score the word with index 34
# The model for word having index LEG did not score the word with index 34
# The model for word having index SAY-1P did not score the word with index 35
# The model for word having index LEG did not score the word with index 35
# The model for word having index SAY-1P did not score the word with index 36
# The model for word having index LEG did not score the word with index 36
# The model for word having index SAY-1P did not score the word with index 37
# The model for word having index LEG did not score the word with index 37
# The model for word having index SAY-1P did not score the word with index 38
# The model for word having index LEG did not score the word with index 38
# The model for word having index SAY-1P did not score the word with index 39
# The model for word having index LEG did not score the word with index 39
# The model for word having index SAY-1P did not score the word with index 40
# The model for word having index LEG did not score the word with index 40
# The model for word having index SAY-1P did not score the word with index 41
# The model for word having index LEG did not score the word with index 41
# The model for word having index SAY-1P did not score the word with index 42
# The model for word having index LEG did not score the word with index 42
# The model for word having index SAY-1P did not score the word with index 43
# The model for word having index LEG did not score the word with index 43
# The model for word having index SAY-1P did not score the word with index 44
# The model for word having index LEG did not score the word with index 44
# The model for word having index SAY-1P did not score the word with index 45
# The model for word having index LEG did not score the word with index 45
# The model for word having index SAY-1P did not score the word with index 46
# The model for word having index LEG did not score the word with index 46
# The model for word having index SAY-1P did not score the word with index 47
# The model for word having index LEG did not score the word with index 47
# The model for word having index SAY-1P did not score the word with index 48
# The model for word having index LEG did not score the word with index 48
# The model for word having index SAY-1P did not score the word with index 49
# The model for word having index LEG did not score the word with index 49
# The model for word having index SAY-1P did not score the word with index 50
# The model for word having index LEG did not score the word with index 50
# The model for word having index SAY-1P did not score the word with index 51
# The model for word having index LEG did not score the word with index 51
# The model for word having index SAY-1P did not score the word with index 52
# The model for word having index LEG did not score the word with index 52
# The model for word having index SAY-1P did not score the word with index 53
# The model for word having index LEG did not score the word with index 53
# The model for word having index SAY-1P did not score the word with index 54
# The model for word having index LEG did not score the word with index 54
# The model for word having index SAY-1P did not score the word with index 55
# The model for word having index LEG did not score the word with index 55
# The model for word having index SAY-1P did not score the word with index 56
# The model for word having index LEG did not score the word with index 56
# The model for word having index SAY-1P did not score the word with index 57
# The model for word having index LEG did not score the word with index 57
# The model for word having index SAY-1P did not score the word with index 58
# The model for word having index LEG did not score the word with index 58
# The model for word having index SAY-1P did not score the word with index 59
# The model for word having index LEG did not score the word with index 59
# The model for word having index SAY-1P did not score the word with index 60
# The model for word having index LEG did not score the word with index 60
# The model for word having index SAY-1P did not score the word with index 61
# The model for word having index LEG did not score the word with index 61
# The model for word having index SAY-1P did not score the word with index 62
# The model for word having index LEG did not score the word with index 62
# The model for word having index SAY-1P did not score the word with index 63
# The model for word having index LEG did not score the word with index 63
# The model for word having index SAY-1P did not score the word with index 64
# The model for word having index LEG did not score the word with index 64
# The model for word having index SAY-1P did not score the word with index 65
# The model for word having index LEG did not score the word with index 65
# The model for word having index SAY-1P did not score the word with index 66
# The model for word having index LEG did not score the word with index 66
# The model for word having index SAY-1P did not score the word with index 67
# The model for word having index LEG did not score the word with index 67
# The model for word having index SAY-1P did not score the word with index 68
# The model for word having index LEG did not score the word with index 68
# The model for word having index SAY-1P did not score the word with index 69
# The model for word having index LEG did not score the word with index 69
# The model for word having index SAY-1P did not score the word with index 70
# The model for word having index LEG did not score the word with index 70
# The model for word having index SAY-1P did not score the word with index 71
# The model for word having index LEG did not score the word with index 71
# The model for word having index SAY-1P did not score the word with index 72
# The model for word having index LEG did not score the word with index 72
# The model for word having index SAY-1P did not score the word with index 73
# The model for word having index LEG did not score the word with index 73
# The model for word having index SAY-1P did not score the word with index 74
# The model for word having index LEG did not score the word with index 74
# The model for word having index SAY-1P did not score the word with index 75
# The model for word having index LEG did not score the word with index 75
# The model for word having index SAY-1P did not score the word with index 76
# The model for word having index LEG did not score the word with index 76
# The model for word having index SAY-1P did not score the word with index 77
# The model for word having index LEG did not score the word with index 77
# The model for word having index SAY-1P did not score the word with index 78
# The model for word having index LEG did not score the word with index 78
# The model for word having index SAY-1P did not score the word with index 79
# The model for word having index LEG did not score the word with index 79
# The model for word having index SAY-1P did not score the word with index 80
# The model for word having index LEG did not score the word with index 80
# The model for word having index SAY-1P did not score the word with index 81
# The model for word having index LEG did not score the word with index 81
# The model for word having index SAY-1P did not score the word with index 82
# The model for word having index LEG did not score the word with index 82
# The model for word having index SAY-1P did not score the word with index 83
# The model for word having index LEG did not score the word with index 83
# The model for word having index SAY-1P did not score the word with index 84
# The model for word having index LEG did not score the word with index 84
# The model for word having index SAY-1P did not score the word with index 85
# The model for word having index LEG did not score the word with index 85
# The model for word having index SAY-1P did not score the word with index 86
# The model for word having index LEG did not score the word with index 86
# The model for word having index SAY-1P did not score the word with index 87
# The model for word having index LEG did not score the word with index 87
# The model for word having index SAY-1P did not score the word with index 88
# The model for word having index LEG did not score the word with index 88
# The model for word having index SAY-1P did not score the word with index 89
# The model for word having index LEG did not score the word with index 89
# The model for word having index SAY-1P did not score the word with index 90
# The model for word having index LEG did not score the word with index 90
# The model for word having index SAY-1P did not score the word with index 91
# The model for word having index LEG did not score the word with index 91
# The model for word having index SAY-1P did not score the word with index 92
# The model for word having index LEG did not score the word with index 92
# The model for word having index SAY-1P did not score the word with index 93
# The model for word having index LEG did not score the word with index 93
# The model for word having index SAY-1P did not score the word with index 94
# The model for word having index LEG did not score the word with index 94
# The model for word having index SAY-1P did not score the word with index 95
# The model for word having index LEG did not score the word with index 95
# The model for word having index SAY-1P did not score the word with index 96
# The model for word having index LEG did not score the word with index 96
# The model for word having index SAY-1P did not score the word with index 97
# The model for word having index LEG did not score the word with index 97
# The model for word having index SAY-1P did not score the word with index 98
# The model for word having index LEG did not score the word with index 98
# The model for word having index SAY-1P did not score the word with index 99
# The model for word having index LEG did not score the word with index 99
# The model for word having index SAY-1P did not score the word with index 100
# The model for word having index LEG did not score the word with index 100
# The model for word having index SAY-1P did not score the word with index 101
# The model for word having index LEG did not score the word with index 101
# The model for word having index SAY-1P did not score the word with index 102
# The model for word having index LEG did not score the word with index 102
# The model for word having index SAY-1P did not score the word with index 103
# The model for word having index LEG did not score the word with index 103
# The model for word having index SAY-1P did not score the word with index 104
# The model for word having index LEG did not score the word with index 104
# The model for word having index SAY-1P did not score the word with index 105
# The model for word having index LEG did not score the word with index 105
# The model for word having index SAY-1P did not score the word with index 106
# The model for word having index LEG did not score the word with index 106
# The model for word having index SAY-1P did not score the word with index 107
# The model for word having index LEG did not score the word with index 107
# The model for word having index SAY-1P did not score the word with index 108
# The model for word having index LEG did not score the word with index 108
# The model for word having index SAY-1P did not score the word with index 109
# The model for word having index LEG did not score the word with index 109
# The model for word having index SAY-1P did not score the word with index 110
# The model for word having index LEG did not score the word with index 110
# The model for word having index SAY-1P did not score the word with index 111
# The model for word having index LEG did not score the word with index 111
# The model for word having index SAY-1P did not score the word with index 112
# The model for word having index LEG did not score the word with index 112
# The model for word having index SAY-1P did not score the word with index 113
# The model for word having index LEG did not score the word with index 113
# The model for word having index SAY-1P did not score the word with index 114
# The model for word having index LEG did not score the word with index 114
# The model for word having index SAY-1P did not score the word with index 115
# The model for word having index LEG did not score the word with index 115
# The model for word having index SAY-1P did not score the word with index 116
# The model for word having index LEG did not score the word with index 116
# The model for word having index SAY-1P did not score the word with index 117
# The model for word having index LEG did not score the word with index 117
# The model for word having index SAY-1P did not score the word with index 118
# The model for word having index LEG did not score the word with index 118
# The model for word having index SAY-1P did not score the word with index 119
# The model for word having index LEG did not score the word with index 119
# The model for word having index SAY-1P did not score the word with index 120
# The model for word having index LEG did not score the word with index 120
# The model for word having index SAY-1P did not score the word with index 121
# The model for word having index LEG did not score the word with index 121
# The model for word having index SAY-1P did not score the word with index 122
# The model for word having index LEG did not score the word with index 122
# The model for word having index SAY-1P did not score the word with index 123
# The model for word having index LEG did not score the word with index 123
# The model for word having index SAY-1P did not score the word with index 124
# The model for word having index LEG did not score the word with index 124
# The model for word having index SAY-1P did not score the word with index 125
# The model for word having index LEG did not score the word with index 125
# The model for word having index SAY-1P did not score the word with index 126
# The model for word having index LEG did not score the word with index 126
# The model for word having index SAY-1P did not score the word with index 127
# The model for word having index LEG did not score the word with index 127
# The model for word having index SAY-1P did not score the word with index 128
# The model for word having index LEG did not score the word with index 128
# The model for word having index SAY-1P did not score the word with index 129
# The model for word having index LEG did not score the word with index 129
# The model for word having index SAY-1P did not score the word with index 130
# The model for word having index LEG did not score the word with index 130
# The model for word having index SAY-1P did not score the word with index 131
# The model for word having index LEG did not score the word with index 131
# The model for word having index SAY-1P did not score the word with index 132
# The model for word having index LEG did not score the word with index 132
# The model for word having index SAY-1P did not score the word with index 133
# The model for word having index LEG did not score the word with index 133
# The model for word having index SAY-1P did not score the word with index 134
# The model for word having index LEG did not score the word with index 134
# The model for word having index SAY-1P did not score the word with index 135
# The model for word having index LEG did not score the word with index 135
# The model for word having index SAY-1P did not score the word with index 136
# The model for word having index LEG did not score the word with index 136
# The model for word having index SAY-1P did not score the word with index 137
# The model for word having index LEG did not score the word with index 137
# The model for word having index SAY-1P did not score the word with index 138
# The model for word having index LEG did not score the word with index 138
# The model for word having index SAY-1P did not score the word with index 139
# The model for word having index LEG did not score the word with index 139
# The model for word having index SAY-1P did not score the word with index 140
# The model for word having index LEG did not score the word with index 140
# The model for word having index SAY-1P did not score the word with index 141
# The model for word having index LEG did not score the word with index 141
# The model for word having index SAY-1P did not score the word with index 142
# The model for word having index LEG did not score the word with index 142
# The model for word having index SAY-1P did not score the word with index 143
# The model for word having index LEG did not score the word with index 143
# The model for word having index SAY-1P did not score the word with index 144
# The model for word having index LEG did not score the word with index 144
# The model for word having index SAY-1P did not score the word with index 145
# The model for word having index LEG did not score the word with index 145
# The model for word having index SAY-1P did not score the word with index 146
# The model for word having index LEG did not score the word with index 146
# The model for word having index SAY-1P did not score the word with index 147
# The model for word having index LEG did not score the word with index 147
# The model for word having index SAY-1P did not score the word with index 148
# The model for word having index LEG did not score the word with index 148
# The model for word having index SAY-1P did not score the word with index 149
# The model for word having index LEG did not score the word with index 149
# The model for word having index SAY-1P did not score the word with index 150
# The model for word having index LEG did not score the word with index 150
# The model for word having index SAY-1P did not score the word with index 151
# The model for word having index LEG did not score the word with index 151
# The model for word having index SAY-1P did not score the word with index 152
# The model for word having index LEG did not score the word with index 152
# The model for word having index SAY-1P did not score the word with index 153
# The model for word having index LEG did not score the word with index 153
# The model for word having index SAY-1P did not score the word with index 154
# The model for word having index LEG did not score the word with index 154
# The model for word having index SAY-1P did not score the word with index 155
# The model for word having index LEG did not score the word with index 155
# The model for word having index SAY-1P did not score the word with index 156
# The model for word having index LEG did not score the word with index 156
# The model for word having index SAY-1P did not score the word with index 157
# The model for word having index LEG did not score the word with index 157
# The model for word having index SAY-1P did not score the word with index 158
# The model for word having index LEG did not score the word with index 158
# The model for word having index SAY-1P did not score the word with index 159
# The model for word having index LEG did not score the word with index 159
# The model for word having index SAY-1P did not score the word with index 160
# The model for word having index LEG did not score the word with index 160
# The model for word having index SAY-1P did not score the word with index 161
# The model for word having index LEG did not score the word with index 161
# The model for word having index SAY-1P did not score the word with index 162
# The model for word having index LEG did not score the word with index 162
# The model for word having index SAY-1P did not score the word with index 163
# The model for word having index LEG did not score the word with index 163
# The model for word having index SAY-1P did not score the word with index 164
# The model for word having index LEG did not score the word with index 164
# The model for word having index SAY-1P did not score the word with index 165
# The model for word having index LEG did not score the word with index 165
# The model for word having index SAY-1P did not score the word with index 166
# The model for word having index LEG did not score the word with index 166
# The model for word having index SAY-1P did not score the word with index 167
# The model for word having index LEG did not score the word with index 167
# The model for word having index SAY-1P did not score the word with index 168
# The model for word having index LEG did not score the word with index 168
# The model for word having index SAY-1P did not score the word with index 169
# The model for word having index LEG did not score the word with index 169
# The model for word having index SAY-1P did not score the word with index 170
# The model for word having index LEG did not score the word with index 170
# The model for word having index SAY-1P did not score the word with index 171
# The model for word having index LEG did not score the word with index 171
# The model for word having index SAY-1P did not score the word with index 172
# The model for word having index LEG did not score the word with index 172
# The model for word having index SAY-1P did not score the word with index 173
# The model for word having index LEG did not score the word with index 173
# The model for word having index SAY-1P did not score the word with index 174
# The model for word having index LEG did not score the word with index 174
# The model for word having index SAY-1P did not score the word with index 175
# The model for word having index LEG did not score the word with index 175
# The model for word having index SAY-1P did not score the word with index 176
# The model for word having index LEG did not score the word with index 176
# The model for word having index SAY-1P did not score the word with index 177
# The model for word having index LEG did not score the word with index 177
#
# **** WER = 0.5674157303370787
# Total correct: 77 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#   100: *IX NEW CAR *ARRIVE                                           POSS NEW CAR BREAK-DOWN
#     2: JOHN *NEW *GIVE1                                              JOHN WRITE HOMEWORK
#    67: JOHN FUTURE *MARY BUY HOUSE                                   JOHN FUTURE NOT BUY HOUSE
#     7: *SOMETHING-ONE CAN *ARRIVE *ARRIVE                            JOHN CAN GO CAN
#   201: JOHN *MARY *LOVE *JOHN *GIVE1 HOUSE                           JOHN TELL MARY IX-1P BUY HOUSE
#    74: *IX *GO *MARY MARY                                            JOHN NOT VISIT MARY
#   119: *VISIT *BUY1 IX *BOX *IX                                      SUE BUY IX CAR BLUE
#    12: *IX *WHAT *WHAT *CAR                                          JOHN CAN GO CAN
#    77: *JOHN BLAME *LOVE                                             ANN BLAME MARY
#   142: JOHN BUY YESTERDAY WHAT BOOK                                  JOHN BUY YESTERDAY WHAT BOOK
#   107: JOHN *IX *HAVE *ARRIVE *JOHN                                  JOHN POSS FRIEND HAVE CANDY
#    84: *JOHN *GIVE1 *VISIT BOOK                                      IX-1P FIND SOMETHING-ONE BOOK
#    21: JOHN *GIVE1 *JOHN *NOT *CAR *CAR *FUTURE *MARY                JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *IX IX *WHO IX                                           JOHN LIKE IX IX IX
#    89: *MARY IX *IX *IX IX *ARRIVE *BOOK                             JOHN IX GIVE MAN IX NEW COAT
#    71: JOHN *FINISH VISIT MARY                                       JOHN WILL VISIT MARY
#    92: JOHN *IX IX *IX *IX BOOK                                      JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    90: JOHN *SOMETHING-ONE IX *IX *VISIT *ARRIVE                     JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    30: JOHN *MARY *MARY *MARY *MARY                                  JOHN LIKE IX IX IX
#   193: JOHN *SOMETHING-ONE *VISIT BOX                                JOHN GIVE GIRL BOX
#    36: *VISIT *VISIT *GIVE *GO *MARY *IX                             MARY VEGETABLE KNOW IX LIKE CORN1
#   139: JOHN *BUY1 WHAT *MARY BOOK                                    JOHN BUY WHAT YESTERDAY BOOK
#   167: JOHN *MARY *GO LOVE MARY                                      JOHN IX SAY LOVE MARY
#    40: *MARY *GO *GIVE MARY *MARY                                    JOHN IX THINK MARY LOVE
#    28: JOHN *WHO IX IX *LOVE                                         JOHN LIKE IX IX IX
#   171: JOHN MARY BLAME                                               JOHN MARY BLAME
#    43: JOHN *IX BUY HOUSE                                            JOHN MUST BUY HOUSE
#   108: *IX ARRIVE                                                    WOMAN ARRIVE
#   174: *CAN *GIVE1 GIVE1 *YESTERDAY *WHAT                            PEOPLE GROUP GIVE1 JANA TOY
#   113: IX CAR *IX *MARY *BOX                                         IX CAR BLUE SUE BUY
#    50: *JOHN *FUTURE *GIVE1 CAR *JOHN                                FUTURE JOHN BUY CAR SHOULD
#   199: *JOHN *ARRIVE *GO                                             LIKE CHOCOLATE WHO
#   158: LOVE JOHN WHO                                                 LOVE JOHN WHO
#    54: JOHN SHOULD NOT BUY HOUSE                                     JOHN SHOULD NOT BUY HOUSE
#   105: JOHN *FRANK                                                   JOHN LEG
#   184: *IX BOY *GIVE1 TEACHER *YESTERDAY                             ALL BOY GIVE TEACHER APPLE
#    57: *MARY *VISIT VISIT MARY                                       JOHN DECIDE VISIT MARY
#   122: JOHN *BUY BOOK                                                JOHN READ BOOK
#   189: JOHN *SOMETHING-ONE *VISIT BOX                                JOHN GIVE GIRL BOX
#   181: JOHN ARRIVE                                                   JOHN ARRIVE

# %%
from my_model_selectors import SelectorBIC

# TODO Choose a feature set and model selector
features_ground = ['norm-rx', 'norm-ry', 'norm-lx','norm-ly','polar-rr', 'polar-rtheta',
                   'polar-lr', 'polar-ltheta','delta-rx', 'delta-ry', 'delta-lx', 'delta-ly']
features = features_ground # change as needed
model_selector = SelectorBIC # change as needed

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# The model for word having index FIND did not score the word with index 0
# The model for word having index SAY-1P did not score the word with index 0
# The model for word having index LEG did not score the word with index 0
# The model for word having index FIND did not score the word with index 1
# The model for word having index SAY-1P did not score the word with index 1
# The model for word having index LEG did not score the word with index 1
# The model for word having index FIND did not score the word with index 2
# The model for word having index SAY-1P did not score the word with index 2
# The model for word having index LEG did not score the word with index 2
# The model for word having index FIND did not score the word with index 3
# The model for word having index SAY-1P did not score the word with index 3
# The model for word having index LEG did not score the word with index 3
# The model for word having index FIND did not score the word with index 4
# The model for word having index SAY-1P did not score the word with index 4
# The model for word having index LEG did not score the word with index 4
# The model for word having index FIND did not score the word with index 5
# The model for word having index SAY-1P did not score the word with index 5
# The model for word having index LEG did not score the word with index 5
# The model for word having index FIND did not score the word with index 6
# The model for word having index SAY-1P did not score the word with index 6
# The model for word having index LEG did not score the word with index 6
# The model for word having index FIND did not score the word with index 7
# The model for word having index SAY-1P did not score the word with index 7
# The model for word having index LEG did not score the word with index 7
# The model for word having index FIND did not score the word with index 8
# The model for word having index SAY-1P did not score the word with index 8
# The model for word having index LEG did not score the word with index 8
# The model for word having index FIND did not score the word with index 9
# The model for word having index SAY-1P did not score the word with index 9
# The model for word having index LEG did not score the word with index 9
# The model for word having index FIND did not score the word with index 10
# The model for word having index SAY-1P did not score the word with index 10
# The model for word having index LEG did not score the word with index 10
# The model for word having index FIND did not score the word with index 11
# The model for word having index SAY-1P did not score the word with index 11
# The model for word having index LEG did not score the word with index 11
# The model for word having index FIND did not score the word with index 12
# The model for word having index SAY-1P did not score the word with index 12
# The model for word having index LEG did not score the word with index 12
# The model for word having index FIND did not score the word with index 13
# The model for word having index SAY-1P did not score the word with index 13
# The model for word having index LEG did not score the word with index 13
# The model for word having index FIND did not score the word with index 14
# The model for word having index SAY-1P did not score the word with index 14
# The model for word having index LEG did not score the word with index 14
# The model for word having index FIND did not score the word with index 15
# The model for word having index SAY-1P did not score the word with index 15
# The model for word having index LEG did not score the word with index 15
# The model for word having index FIND did not score the word with index 16
# The model for word having index SAY-1P did not score the word with index 16
# The model for word having index LEG did not score the word with index 16
# The model for word having index FIND did not score the word with index 17
# The model for word having index SAY-1P did not score the word with index 17
# The model for word having index LEG did not score the word with index 17
# The model for word having index FIND did not score the word with index 18
# The model for word having index SAY-1P did not score the word with index 18
# The model for word having index LEG did not score the word with index 18
# The model for word having index FIND did not score the word with index 19
# The model for word having index SAY-1P did not score the word with index 19
# The model for word having index LEG did not score the word with index 19
# The model for word having index FIND did not score the word with index 20
# The model for word having index SAY-1P did not score the word with index 20
# The model for word having index LEG did not score the word with index 20
# The model for word having index FIND did not score the word with index 21
# The model for word having index SAY-1P did not score the word with index 21
# The model for word having index LEG did not score the word with index 21
# The model for word having index FIND did not score the word with index 22
# The model for word having index SAY-1P did not score the word with index 22
# The model for word having index LEG did not score the word with index 22
# The model for word having index FIND did not score the word with index 23
# The model for word having index SAY-1P did not score the word with index 23
# The model for word having index LEG did not score the word with index 23
# The model for word having index FIND did not score the word with index 24
# The model for word having index SAY-1P did not score the word with index 24
# The model for word having index LEG did not score the word with index 24
# The model for word having index FIND did not score the word with index 25
# The model for word having index SAY-1P did not score the word with index 25
# The model for word having index LEG did not score the word with index 25
# The model for word having index FIND did not score the word with index 26
# The model for word having index SAY-1P did not score the word with index 26
# The model for word having index LEG did not score the word with index 26
# The model for word having index FIND did not score the word with index 27
# The model for word having index SAY-1P did not score the word with index 27
# The model for word having index LEG did not score the word with index 27
# The model for word having index FIND did not score the word with index 28
# The model for word having index SAY-1P did not score the word with index 28
# The model for word having index LEG did not score the word with index 28
# The model for word having index FIND did not score the word with index 29
# The model for word having index SAY-1P did not score the word with index 29
# The model for word having index LEG did not score the word with index 29
# The model for word having index FIND did not score the word with index 30
# The model for word having index SAY-1P did not score the word with index 30
# The model for word having index LEG did not score the word with index 30
# The model for word having index FIND did not score the word with index 31
# The model for word having index SAY-1P did not score the word with index 31
# The model for word having index LEG did not score the word with index 31
# The model for word having index FIND did not score the word with index 32
# The model for word having index SAY-1P did not score the word with index 32
# The model for word having index LEG did not score the word with index 32
# The model for word having index FIND did not score the word with index 33
# The model for word having index SAY-1P did not score the word with index 33
# The model for word having index LEG did not score the word with index 33
# The model for word having index FIND did not score the word with index 34
# The model for word having index SAY-1P did not score the word with index 34
# The model for word having index LEG did not score the word with index 34
# The model for word having index FIND did not score the word with index 35
# The model for word having index SAY-1P did not score the word with index 35
# The model for word having index LEG did not score the word with index 35
# The model for word having index FIND did not score the word with index 36
# The model for word having index SAY-1P did not score the word with index 36
# The model for word having index LEG did not score the word with index 36
# The model for word having index FIND did not score the word with index 37
# The model for word having index SAY-1P did not score the word with index 37
# The model for word having index LEG did not score the word with index 37
# The model for word having index FIND did not score the word with index 38
# The model for word having index SAY-1P did not score the word with index 38
# The model for word having index LEG did not score the word with index 38
# The model for word having index FIND did not score the word with index 39
# The model for word having index SAY-1P did not score the word with index 39
# The model for word having index LEG did not score the word with index 39
# The model for word having index FIND did not score the word with index 40
# The model for word having index SAY-1P did not score the word with index 40
# The model for word having index LEG did not score the word with index 40
# The model for word having index FIND did not score the word with index 41
# The model for word having index SAY-1P did not score the word with index 41
# The model for word having index LEG did not score the word with index 41
# The model for word having index FIND did not score the word with index 42
# The model for word having index SAY-1P did not score the word with index 42
# The model for word having index LEG did not score the word with index 42
# The model for word having index FIND did not score the word with index 43
# The model for word having index SAY-1P did not score the word with index 43
# The model for word having index LEG did not score the word with index 43
# The model for word having index FIND did not score the word with index 44
# The model for word having index SAY-1P did not score the word with index 44
# The model for word having index LEG did not score the word with index 44
# The model for word having index FIND did not score the word with index 45
# The model for word having index SAY-1P did not score the word with index 45
# The model for word having index LEG did not score the word with index 45
# The model for word having index FIND did not score the word with index 46
# The model for word having index SAY-1P did not score the word with index 46
# The model for word having index LEG did not score the word with index 46
# The model for word having index FIND did not score the word with index 47
# The model for word having index SAY-1P did not score the word with index 47
# The model for word having index LEG did not score the word with index 47
# The model for word having index FIND did not score the word with index 48
# The model for word having index SAY-1P did not score the word with index 48
# The model for word having index LEG did not score the word with index 48
# The model for word having index FIND did not score the word with index 49
# The model for word having index SAY-1P did not score the word with index 49
# The model for word having index LEG did not score the word with index 49
# The model for word having index FIND did not score the word with index 50
# The model for word having index SAY-1P did not score the word with index 50
# The model for word having index LEG did not score the word with index 50
# The model for word having index FIND did not score the word with index 51
# The model for word having index SAY-1P did not score the word with index 51
# The model for word having index LEG did not score the word with index 51
# The model for word having index FIND did not score the word with index 52
# The model for word having index SAY-1P did not score the word with index 52
# The model for word having index LEG did not score the word with index 52
# The model for word having index FIND did not score the word with index 53
# The model for word having index SAY-1P did not score the word with index 53
# The model for word having index LEG did not score the word with index 53
# The model for word having index FIND did not score the word with index 54
# The model for word having index SAY-1P did not score the word with index 54
# The model for word having index LEG did not score the word with index 54
# The model for word having index FIND did not score the word with index 55
# The model for word having index SAY-1P did not score the word with index 55
# The model for word having index LEG did not score the word with index 55
# The model for word having index FIND did not score the word with index 56
# The model for word having index SAY-1P did not score the word with index 56
# The model for word having index LEG did not score the word with index 56
# The model for word having index FIND did not score the word with index 57
# The model for word having index SAY-1P did not score the word with index 57
# The model for word having index LEG did not score the word with index 57
# The model for word having index FIND did not score the word with index 58
# The model for word having index SAY-1P did not score the word with index 58
# The model for word having index LEG did not score the word with index 58
# The model for word having index FIND did not score the word with index 59
# The model for word having index SAY-1P did not score the word with index 59
# The model for word having index LEG did not score the word with index 59
# The model for word having index FIND did not score the word with index 60
# The model for word having index SAY-1P did not score the word with index 60
# The model for word having index LEG did not score the word with index 60
# The model for word having index FIND did not score the word with index 61
# The model for word having index SAY-1P did not score the word with index 61
# The model for word having index LEG did not score the word with index 61
# The model for word having index FIND did not score the word with index 62
# The model for word having index SAY-1P did not score the word with index 62
# The model for word having index LEG did not score the word with index 62
# The model for word having index FIND did not score the word with index 63
# The model for word having index SAY-1P did not score the word with index 63
# The model for word having index LEG did not score the word with index 63
# The model for word having index FIND did not score the word with index 64
# The model for word having index SAY-1P did not score the word with index 64
# The model for word having index LEG did not score the word with index 64
# The model for word having index FIND did not score the word with index 65
# The model for word having index SAY-1P did not score the word with index 65
# The model for word having index LEG did not score the word with index 65
# The model for word having index FIND did not score the word with index 66
# The model for word having index SAY-1P did not score the word with index 66
# The model for word having index LEG did not score the word with index 66
# The model for word having index FIND did not score the word with index 67
# The model for word having index SAY-1P did not score the word with index 67
# The model for word having index LEG did not score the word with index 67
# The model for word having index FIND did not score the word with index 68
# The model for word having index SAY-1P did not score the word with index 68
# The model for word having index LEG did not score the word with index 68
# The model for word having index FIND did not score the word with index 69
# The model for word having index SAY-1P did not score the word with index 69
# The model for word having index LEG did not score the word with index 69
# The model for word having index FIND did not score the word with index 70
# The model for word having index SAY-1P did not score the word with index 70
# The model for word having index LEG did not score the word with index 70
# The model for word having index FIND did not score the word with index 71
# The model for word having index SAY-1P did not score the word with index 71
# The model for word having index LEG did not score the word with index 71
# The model for word having index FIND did not score the word with index 72
# The model for word having index SAY-1P did not score the word with index 72
# The model for word having index LEG did not score the word with index 72
# The model for word having index FIND did not score the word with index 73
# The model for word having index SAY-1P did not score the word with index 73
# The model for word having index LEG did not score the word with index 73
# The model for word having index FIND did not score the word with index 74
# The model for word having index SAY-1P did not score the word with index 74
# The model for word having index LEG did not score the word with index 74
# The model for word having index FIND did not score the word with index 75
# The model for word having index SAY-1P did not score the word with index 75
# The model for word having index LEG did not score the word with index 75
# The model for word having index FIND did not score the word with index 76
# The model for word having index SAY-1P did not score the word with index 76
# The model for word having index LEG did not score the word with index 76
# The model for word having index FIND did not score the word with index 77
# The model for word having index SAY-1P did not score the word with index 77
# The model for word having index LEG did not score the word with index 77
# The model for word having index FIND did not score the word with index 78
# The model for word having index SAY-1P did not score the word with index 78
# The model for word having index LEG did not score the word with index 78
# The model for word having index FIND did not score the word with index 79
# The model for word having index SAY-1P did not score the word with index 79
# The model for word having index LEG did not score the word with index 79
# The model for word having index FIND did not score the word with index 80
# The model for word having index SAY-1P did not score the word with index 80
# The model for word having index LEG did not score the word with index 80
# The model for word having index FIND did not score the word with index 81
# The model for word having index SAY-1P did not score the word with index 81
# The model for word having index LEG did not score the word with index 81
# The model for word having index FIND did not score the word with index 82
# The model for word having index SAY-1P did not score the word with index 82
# The model for word having index LEG did not score the word with index 82
# The model for word having index FIND did not score the word with index 83
# The model for word having index SAY-1P did not score the word with index 83
# The model for word having index LEG did not score the word with index 83
# The model for word having index FIND did not score the word with index 84
# The model for word having index SAY-1P did not score the word with index 84
# The model for word having index LEG did not score the word with index 84
# The model for word having index FIND did not score the word with index 85
# The model for word having index SAY-1P did not score the word with index 85
# The model for word having index LEG did not score the word with index 85
# The model for word having index FIND did not score the word with index 86
# The model for word having index SAY-1P did not score the word with index 86
# The model for word having index LEG did not score the word with index 86
# The model for word having index FIND did not score the word with index 87
# The model for word having index SAY-1P did not score the word with index 87
# The model for word having index LEG did not score the word with index 87
# The model for word having index FIND did not score the word with index 88
# The model for word having index SAY-1P did not score the word with index 88
# The model for word having index LEG did not score the word with index 88
# The model for word having index FIND did not score the word with index 89
# The model for word having index SAY-1P did not score the word with index 89
# The model for word having index LEG did not score the word with index 89
# The model for word having index FIND did not score the word with index 90
# The model for word having index SAY-1P did not score the word with index 90
# The model for word having index LEG did not score the word with index 90
# The model for word having index FIND did not score the word with index 91
# The model for word having index SAY-1P did not score the word with index 91
# The model for word having index LEG did not score the word with index 91
# The model for word having index FIND did not score the word with index 92
# The model for word having index SAY-1P did not score the word with index 92
# The model for word having index LEG did not score the word with index 92
# The model for word having index FIND did not score the word with index 93
# The model for word having index SAY-1P did not score the word with index 93
# The model for word having index LEG did not score the word with index 93
# The model for word having index FIND did not score the word with index 94
# The model for word having index SAY-1P did not score the word with index 94
# The model for word having index LEG did not score the word with index 94
# The model for word having index FIND did not score the word with index 95
# The model for word having index SAY-1P did not score the word with index 95
# The model for word having index LEG did not score the word with index 95
# The model for word having index FIND did not score the word with index 96
# The model for word having index SAY-1P did not score the word with index 96
# The model for word having index LEG did not score the word with index 96
# The model for word having index FIND did not score the word with index 97
# The model for word having index SAY-1P did not score the word with index 97
# The model for word having index LEG did not score the word with index 97
# The model for word having index FIND did not score the word with index 98
# The model for word having index SAY-1P did not score the word with index 98
# The model for word having index LEG did not score the word with index 98
# The model for word having index FIND did not score the word with index 99
# The model for word having index SAY-1P did not score the word with index 99
# The model for word having index LEG did not score the word with index 99
# The model for word having index FIND did not score the word with index 100
# The model for word having index SAY-1P did not score the word with index 100
# The model for word having index LEG did not score the word with index 100
# The model for word having index FIND did not score the word with index 101
# The model for word having index SAY-1P did not score the word with index 101
# The model for word having index LEG did not score the word with index 101
# The model for word having index FIND did not score the word with index 102
# The model for word having index SAY-1P did not score the word with index 102
# The model for word having index LEG did not score the word with index 102
# The model for word having index FIND did not score the word with index 103
# The model for word having index SAY-1P did not score the word with index 103
# The model for word having index LEG did not score the word with index 103
# The model for word having index FIND did not score the word with index 104
# The model for word having index SAY-1P did not score the word with index 104
# The model for word having index LEG did not score the word with index 104
# The model for word having index FIND did not score the word with index 105
# The model for word having index SAY-1P did not score the word with index 105
# The model for word having index LEG did not score the word with index 105
# The model for word having index FIND did not score the word with index 106
# The model for word having index SAY-1P did not score the word with index 106
# The model for word having index LEG did not score the word with index 106
# The model for word having index FIND did not score the word with index 107
# The model for word having index SAY-1P did not score the word with index 107
# The model for word having index LEG did not score the word with index 107
# The model for word having index FIND did not score the word with index 108
# The model for word having index SAY-1P did not score the word with index 108
# The model for word having index LEG did not score the word with index 108
# The model for word having index FIND did not score the word with index 109
# The model for word having index SAY-1P did not score the word with index 109
# The model for word having index LEG did not score the word with index 109
# The model for word having index FIND did not score the word with index 110
# The model for word having index SAY-1P did not score the word with index 110
# The model for word having index LEG did not score the word with index 110
# The model for word having index FIND did not score the word with index 111
# The model for word having index SAY-1P did not score the word with index 111
# The model for word having index LEG did not score the word with index 111
# The model for word having index FIND did not score the word with index 112
# The model for word having index SAY-1P did not score the word with index 112
# The model for word having index LEG did not score the word with index 112
# The model for word having index FIND did not score the word with index 113
# The model for word having index SAY-1P did not score the word with index 113
# The model for word having index LEG did not score the word with index 113
# The model for word having index FIND did not score the word with index 114
# The model for word having index SAY-1P did not score the word with index 114
# The model for word having index LEG did not score the word with index 114
# The model for word having index FIND did not score the word with index 115
# The model for word having index SAY-1P did not score the word with index 115
# The model for word having index LEG did not score the word with index 115
# The model for word having index FIND did not score the word with index 116
# The model for word having index SAY-1P did not score the word with index 116
# The model for word having index LEG did not score the word with index 116
# The model for word having index FIND did not score the word with index 117
# The model for word having index SAY-1P did not score the word with index 117
# The model for word having index LEG did not score the word with index 117
# The model for word having index FIND did not score the word with index 118
# The model for word having index SAY-1P did not score the word with index 118
# The model for word having index LEG did not score the word with index 118
# The model for word having index FIND did not score the word with index 119
# The model for word having index SAY-1P did not score the word with index 119
# The model for word having index LEG did not score the word with index 119
# The model for word having index FIND did not score the word with index 120
# The model for word having index SAY-1P did not score the word with index 120
# The model for word having index LEG did not score the word with index 120
# The model for word having index FIND did not score the word with index 121
# The model for word having index SAY-1P did not score the word with index 121
# The model for word having index LEG did not score the word with index 121
# The model for word having index FIND did not score the word with index 122
# The model for word having index SAY-1P did not score the word with index 122
# The model for word having index LEG did not score the word with index 122
# The model for word having index FIND did not score the word with index 123
# The model for word having index SAY-1P did not score the word with index 123
# The model for word having index LEG did not score the word with index 123
# The model for word having index FIND did not score the word with index 124
# The model for word having index SAY-1P did not score the word with index 124
# The model for word having index LEG did not score the word with index 124
# The model for word having index FIND did not score the word with index 125
# The model for word having index SAY-1P did not score the word with index 125
# The model for word having index LEG did not score the word with index 125
# The model for word having index FIND did not score the word with index 126
# The model for word having index SAY-1P did not score the word with index 126
# The model for word having index LEG did not score the word with index 126
# The model for word having index FIND did not score the word with index 127
# The model for word having index SAY-1P did not score the word with index 127
# The model for word having index LEG did not score the word with index 127
# The model for word having index FIND did not score the word with index 128
# The model for word having index SAY-1P did not score the word with index 128
# The model for word having index LEG did not score the word with index 128
# The model for word having index FIND did not score the word with index 129
# The model for word having index SAY-1P did not score the word with index 129
# The model for word having index LEG did not score the word with index 129
# The model for word having index FIND did not score the word with index 130
# The model for word having index SAY-1P did not score the word with index 130
# The model for word having index LEG did not score the word with index 130
# The model for word having index FIND did not score the word with index 131
# The model for word having index SAY-1P did not score the word with index 131
# The model for word having index LEG did not score the word with index 131
# The model for word having index FIND did not score the word with index 132
# The model for word having index SAY-1P did not score the word with index 132
# The model for word having index LEG did not score the word with index 132
# The model for word having index FIND did not score the word with index 133
# The model for word having index SAY-1P did not score the word with index 133
# The model for word having index LEG did not score the word with index 133
# The model for word having index FIND did not score the word with index 134
# The model for word having index SAY-1P did not score the word with index 134
# The model for word having index LEG did not score the word with index 134
# The model for word having index FIND did not score the word with index 135
# The model for word having index SAY-1P did not score the word with index 135
# The model for word having index LEG did not score the word with index 135
# The model for word having index FIND did not score the word with index 136
# The model for word having index SAY-1P did not score the word with index 136
# The model for word having index LEG did not score the word with index 136
# The model for word having index FIND did not score the word with index 137
# The model for word having index SAY-1P did not score the word with index 137
# The model for word having index LEG did not score the word with index 137
# The model for word having index FIND did not score the word with index 138
# The model for word having index SAY-1P did not score the word with index 138
# The model for word having index LEG did not score the word with index 138
# The model for word having index FIND did not score the word with index 139
# The model for word having index SAY-1P did not score the word with index 139
# The model for word having index LEG did not score the word with index 139
# The model for word having index FIND did not score the word with index 140
# The model for word having index SAY-1P did not score the word with index 140
# The model for word having index LEG did not score the word with index 140
# The model for word having index FIND did not score the word with index 141
# The model for word having index SAY-1P did not score the word with index 141
# The model for word having index LEG did not score the word with index 141
# The model for word having index FIND did not score the word with index 142
# The model for word having index SAY-1P did not score the word with index 142
# The model for word having index LEG did not score the word with index 142
# The model for word having index FIND did not score the word with index 143
# The model for word having index SAY-1P did not score the word with index 143
# The model for word having index LEG did not score the word with index 143
# The model for word having index FIND did not score the word with index 144
# The model for word having index SAY-1P did not score the word with index 144
# The model for word having index LEG did not score the word with index 144
# The model for word having index FIND did not score the word with index 145
# The model for word having index SAY-1P did not score the word with index 145
# The model for word having index LEG did not score the word with index 145
# The model for word having index FIND did not score the word with index 146
# The model for word having index SAY-1P did not score the word with index 146
# The model for word having index LEG did not score the word with index 146
# The model for word having index FIND did not score the word with index 147
# The model for word having index SAY-1P did not score the word with index 147
# The model for word having index LEG did not score the word with index 147
# The model for word having index FIND did not score the word with index 148
# The model for word having index SAY-1P did not score the word with index 148
# The model for word having index LEG did not score the word with index 148
# The model for word having index FIND did not score the word with index 149
# The model for word having index SAY-1P did not score the word with index 149
# The model for word having index LEG did not score the word with index 149
# The model for word having index FIND did not score the word with index 150
# The model for word having index SAY-1P did not score the word with index 150
# The model for word having index LEG did not score the word with index 150
# The model for word having index FIND did not score the word with index 151
# The model for word having index SAY-1P did not score the word with index 151
# The model for word having index LEG did not score the word with index 151
# The model for word having index FIND did not score the word with index 152
# The model for word having index SAY-1P did not score the word with index 152
# The model for word having index LEG did not score the word with index 152
# The model for word having index FIND did not score the word with index 153
# The model for word having index SAY-1P did not score the word with index 153
# The model for word having index LEG did not score the word with index 153
# The model for word having index FIND did not score the word with index 154
# The model for word having index SAY-1P did not score the word with index 154
# The model for word having index LEG did not score the word with index 154
# The model for word having index FIND did not score the word with index 155
# The model for word having index SAY-1P did not score the word with index 155
# The model for word having index LEG did not score the word with index 155
# The model for word having index FIND did not score the word with index 156
# The model for word having index SAY-1P did not score the word with index 156
# The model for word having index LEG did not score the word with index 156
# The model for word having index FIND did not score the word with index 157
# The model for word having index SAY-1P did not score the word with index 157
# The model for word having index LEG did not score the word with index 157
# The model for word having index FIND did not score the word with index 158
# The model for word having index SAY-1P did not score the word with index 158
# The model for word having index LEG did not score the word with index 158
# The model for word having index FIND did not score the word with index 159
# The model for word having index SAY-1P did not score the word with index 159
# The model for word having index LEG did not score the word with index 159
# The model for word having index FIND did not score the word with index 160
# The model for word having index SAY-1P did not score the word with index 160
# The model for word having index LEG did not score the word with index 160
# The model for word having index FIND did not score the word with index 161
# The model for word having index SAY-1P did not score the word with index 161
# The model for word having index LEG did not score the word with index 161
# The model for word having index FIND did not score the word with index 162
# The model for word having index SAY-1P did not score the word with index 162
# The model for word having index LEG did not score the word with index 162
# The model for word having index FIND did not score the word with index 163
# The model for word having index SAY-1P did not score the word with index 163
# The model for word having index LEG did not score the word with index 163
# The model for word having index FIND did not score the word with index 164
# The model for word having index SAY-1P did not score the word with index 164
# The model for word having index LEG did not score the word with index 164
# The model for word having index FIND did not score the word with index 165
# The model for word having index SAY-1P did not score the word with index 165
# The model for word having index LEG did not score the word with index 165
# The model for word having index FIND did not score the word with index 166
# The model for word having index SAY-1P did not score the word with index 166
# The model for word having index LEG did not score the word with index 166
# The model for word having index FIND did not score the word with index 167
# The model for word having index SAY-1P did not score the word with index 167
# The model for word having index LEG did not score the word with index 167
# The model for word having index FIND did not score the word with index 168
# The model for word having index SAY-1P did not score the word with index 168
# The model for word having index LEG did not score the word with index 168
# The model for word having index FIND did not score the word with index 169
# The model for word having index SAY-1P did not score the word with index 169
# The model for word having index LEG did not score the word with index 169
# The model for word having index FIND did not score the word with index 170
# The model for word having index SAY-1P did not score the word with index 170
# The model for word having index LEG did not score the word with index 170
# The model for word having index FIND did not score the word with index 171
# The model for word having index SAY-1P did not score the word with index 171
# The model for word having index LEG did not score the word with index 171
# The model for word having index FIND did not score the word with index 172
# The model for word having index SAY-1P did not score the word with index 172
# The model for word having index LEG did not score the word with index 172
# The model for word having index FIND did not score the word with index 173
# The model for word having index SAY-1P did not score the word with index 173
# The model for word having index LEG did not score the word with index 173
# The model for word having index FIND did not score the word with index 174
# The model for word having index SAY-1P did not score the word with index 174
# The model for word having index LEG did not score the word with index 174
# The model for word having index FIND did not score the word with index 175
# The model for word having index SAY-1P did not score the word with index 175
# The model for word having index LEG did not score the word with index 175
# The model for word having index FIND did not score the word with index 176
# The model for word having index SAY-1P did not score the word with index 176
# The model for word having index LEG did not score the word with index 176
# The model for word having index FIND did not score the word with index 177
# The model for word having index SAY-1P did not score the word with index 177
# The model for word having index LEG did not score the word with index 177
#
# **** WER = 0.47191011235955055
# Total correct: 94 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#     2: JOHN WRITE *ARRIVE                                            JOHN WRITE HOMEWORK
#    67: JOHN FUTURE *MARY BUY HOUSE                                   JOHN FUTURE NOT BUY HOUSE
#     7: JOHN *PEOPLE *MARY CAN                                        JOHN CAN GO CAN
#   201: JOHN *MAN *IX *WOMAN BUY HOUSE                                JOHN TELL MARY IX-1P BUY HOUSE
#    74: *IX *MARY *MARY MARY                                          JOHN NOT VISIT MARY
#   119: *MARY *BUY1 IX *JOHN *IX                                      SUE BUY IX CAR BLUE
#    12: JOHN CAN *GO1 CAN                                             JOHN CAN GO CAN
#    77: *JOHN BLAME MARY                                              ANN BLAME MARY
#   142: JOHN BUY YESTERDAY WHAT BOOK                                  JOHN BUY YESTERDAY WHAT BOOK
#   107: JOHN *IX *JOHN *MARY *MARY                                    JOHN POSS FRIEND HAVE CANDY
#    84: *JOHN *ARRIVE *CAR BOOK                                       IX-1P FIND SOMETHING-ONE BOOK
#    21: JOHN *JOHN *JOHN *JOHN *CAR *CAR *FUTURE *MARY                JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN LIKE *LOVE *LIKE IX                                      JOHN LIKE IX IX IX
#    89: *IX IX *IX *WOMAN IX NEW COAT                                 JOHN IX GIVE MAN IX NEW COAT
#    71: JOHN *FUTURE VISIT MARY                                       JOHN WILL VISIT MARY
#    92: JOHN *WOMAN IX *WOMAN WOMAN BOOK                              JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    90: JOHN *IX IX *IX WOMAN BOOK                                    JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    30: JOHN LIKE *MARY IX IX                                         JOHN LIKE IX IX IX
#   193: JOHN *IX GIRL BOX                                             JOHN GIVE GIRL BOX
#    36: MARY *JOHN *GIRL *MARY *MARY *JOHN                            MARY VEGETABLE KNOW IX LIKE CORN1
#   139: JOHN *BUY1 WHAT *WHAT BOOK                                    JOHN BUY WHAT YESTERDAY BOOK
#   167: JOHN IX *MARY LOVE MARY                                       JOHN IX SAY LOVE MARY
#    40: JOHN *MARY *CORN MARY *MARY                                   JOHN IX THINK MARY LOVE
#    28: JOHN LIKE IX *LIKE IX                                         JOHN LIKE IX IX IX
#   171: JOHN *JOHN BLAME                                              JOHN MARY BLAME
#    43: JOHN *JOHN BUY HOUSE                                          JOHN MUST BUY HOUSE
#   108: *JOHN *LOVE                                                   WOMAN ARRIVE
#   174: *JOHN *GIVE1 GIVE1 *JOHN *JOHN                                PEOPLE GROUP GIVE1 JANA TOY
#   113: IX CAR *IX *JOHN *BOX                                         IX CAR BLUE SUE BUY
#    50: *POSS *FRANK BUY CAR *JOHN                                    FUTURE JOHN BUY CAR SHOULD
#   199: *JOHN *ARRIVE WHO                                             LIKE CHOCOLATE WHO
#   158: LOVE *MARY WHO                                                LOVE JOHN WHO
#    54: JOHN *FUTURE *FUTURE BUY HOUSE                                JOHN SHOULD NOT BUY HOUSE
#   105: JOHN *SEE                                                     JOHN LEG
#   184: *IX BOY *GIVE1 TEACHER *IX                                    ALL BOY GIVE TEACHER APPLE
#    57: *IX *JOHN *IX MARY                                            JOHN DECIDE VISIT MARY
#   122: JOHN *GIVE1 BOOK                                              JOHN READ BOOK
#   189: JOHN *IX *JOHN BOX                                            JOHN GIVE GIRL BOX
#   181: JOHN *BOX                                                     JOHN ARRIVE

# %%
features_ground
# Out:
# ['grnd-rx', 'grnd-ry', 'grnd-lx', 'grnd-ly']

# %% [markdown]
# **Question 3:**  Summarize the error results from three combinations of features and model selectors.  What was the "best" combination and why?  What additional information might we use to improve our WER?  For more insight on improving WER, take a look at the introduction to Part 4.
#
# **Answer 3:** I first chose the constant selector and the 4 ground features. The model wasn't doing well with 0.6685 WER. I then chose a DIC Selector with the same 4 ground features and I got a slightly better performing model. The WER was 0.5674. Models selected using DIC can discrimate better. For the last attempt, I tried adding more features but then use BIC to penalize a lot of complexity in terms of states. The features used were the 4 ground features, normalized positions of the left and right hands as well as polar features. The WER turned out to be the best with value 0.4719. By adding more features but then compensating for over-fitting by using BIC, I was able to get the best model so far.

# %% [markdown]
# <a id='part3_test'></a>
# ### Recognizer Unit Tests
# Run the following unit tests as a sanity check on the defined recognizer.  The test simply looks for some valid values but is not exhaustive. However, the project should not be submitted if these tests don't pass.

# %%
from asl_test_recognizer import TestRecognize
suite = unittest.TestLoader().loadTestsFromModule(TestRecognize())
unittest.TextTestRunner().run(suite)
# Out:
# The model for word having index FIND did not score the word with index 0
# The model for word having index LEG did not score the word with index 0
# The model for word having index CANDY did not score the word with index 0
# The model for word having index OLD did not score the word with index 0
# The model for word having index BORROW did not score the word with index 0
# The model for word having index FIND did not score the word with index 1
# The model for word having index LEG did not score the word with index 1
# The model for word having index CANDY did not score the word with index 1
# The model for word having index OLD did not score the word with index 1
# The model for word having index BORROW did not score the word with index 1
# The model for word having index FIND did not score the word with index 2
# The model for word having index LEG did not score the word with index 2
# The model for word having index CANDY did not score the word with index 2
# The model for word having index OLD did not score the word with index 2
# The model for word having index BORROW did not score the word with index 2
# The model for word having index FIND did not score the word with index 3
# The model for word having index LEG did not score the word with index 3
# The model for word having index CANDY did not score the word with index 3
# The model for word having index OLD did not score the word with index 3
# The model for word having index BORROW did not score the word with index 3
# The model for word having index FIND did not score the word with index 4
# The model for word having index LEG did not score the word with index 4
# The model for word having index CANDY did not score the word with index 4
# The model for word having index OLD did not score the word with index 4
# The model for word having index BORROW did not score the word with index 4
# The model for word having index FIND did not score the word with index 5
# The model for word having index LEG did not score the word with index 5
# The model for word having index CANDY did not score the word with index 5
# The model for word having index OLD did not score the word with index 5
# The model for word having index BORROW did not score the word with index 5
# The model for word having index FIND did not score the word with index 6
# The model for word having index LEG did not score the word with index 6
# The model for word having index CANDY did not score the word with index 6
# The model for word having index OLD did not score the word with index 6
# The model for word having index BORROW did not score the word with index 6
# The model for word having index FIND did not score the word with index 7
# The model for word having index LEG did not score the word with index 7
# The model for word having index CANDY did not score the word with index 7
# The model for word having index OLD did not score the word with index 7
# The model for word having index BORROW did not score the word with index 7
# The model for word having index FIND did not score the word with index 8
# The model for word having index LEG did not score the word with index 8
# The model for word having index CANDY did not score the word with index 8
# The model for word having index OLD did not score the word with index 8
# The model for word having index BORROW did not score the word with index 8
# The model for word having index FIND did not score the word with index 9
# The model for word having index LEG did not score the word with index 9
# The model for word having index CANDY did not score the word with index 9
# The model for word having index OLD did not score the word with index 9
# The model for word having index BORROW did not score the word with index 9
# The model for word having index FIND did not score the word with index 10
# The model for word having index LEG did not score the word with index 10
# The model for word having index CANDY did not score the word with index 10
# The model for word having index OLD did not score the word with index 10
# The model for word having index BORROW did not score the word with index 10
# The model for word having index FIND did not score the word with index 11
# The model for word having index LEG did not score the word with index 11
# The model for word having index CANDY did not score the word with index 11
# The model for word having index OLD did not score the word with index 11
# The model for word having index BORROW did not score the word with index 11
# The model for word having index FIND did not score the word with index 12
# The model for word having index LEG did not score the word with index 12
# The model for word having index CANDY did not score the word with index 12
# The model for word having index OLD did not score the word with index 12
# The model for word having index BORROW did not score the word with index 12
# The model for word having index FIND did not score the word with index 13
# The model for word having index LEG did not score the word with index 13
# The model for word having index CANDY did not score the word with index 13
# The model for word having index OLD did not score the word with index 13
# The model for word having index BORROW did not score the word with index 13
# The model for word having index FIND did not score the word with index 14
# The model for word having index LEG did not score the word with index 14
# The model for word having index CANDY did not score the word with index 14
# The model for word having index OLD did not score the word with index 14
# The model for word having index BORROW did not score the word with index 14
# The model for word having index FIND did not score the word with index 15
# The model for word having index LEG did not score the word with index 15
# The model for word having index CANDY did not score the word with index 15
# The model for word having index OLD did not score the word with index 15
# The model for word having index BORROW did not score the word with index 15
# The model for word having index FIND did not score the word with index 16
# The model for word having index LEG did not score the word with index 16
# The model for word having index CANDY did not score the word with index 16
# The model for word having index OLD did not score the word with index 16
# The model for word having index BORROW did not score the word with index 16
# The model for word having index FIND did not score the word with index 17
# The model for word having index LEG did not score the word with index 17
# The model for word having index CANDY did not score the word with index 17
# The model for word having index OLD did not score the word with index 17
# The model for word having index BORROW did not score the word with index 17
# The model for word having index FIND did not score the word with index 18
# The model for word having index LEG did not score the word with index 18
# The model for word having index CANDY did not score the word with index 18
# The model for word having index OLD did not score the word with index 18
# The model for word having index BORROW did not score the word with index 18
# The model for word having index FIND did not score the word with index 19
# The model for word having index LEG did not score the word with index 19
# The model for word having index CANDY did not score the word with index 19
# The model for word having index OLD did not score the word with index 19
# The model for word having index BORROW did not score the word with index 19
# The model for word having index FIND did not score the word with index 20
# The model for word having index LEG did not score the word with index 20
# The model for word having index CANDY did not score the word with index 20
# The model for word having index OLD did not score the word with index 20
# The model for word having index BORROW did not score the word with index 20
# The model for word having index FIND did not score the word with index 21
# The model for word having index LEG did not score the word with index 21
# The model for word having index CANDY did not score the word with index 21
# The model for word having index OLD did not score the word with index 21
# The model for word having index BORROW did not score the word with index 21
# The model for word having index FIND did not score the word with index 22
# The model for word having index LEG did not score the word with index 22
# The model for word having index CANDY did not score the word with index 22
# The model for word having index OLD did not score the word with index 22
# The model for word having index BORROW did not score the word with index 22
# The model for word having index FIND did not score the word with index 23
# The model for word having index LEG did not score the word with index 23
# The model for word having index CANDY did not score the word with index 23
# The model for word having index OLD did not score the word with index 23
# The model for word having index BORROW did not score the word with index 23
# The model for word having index FIND did not score the word with index 24
# The model for word having index LEG did not score the word with index 24
# The model for word having index CANDY did not score the word with index 24
# The model for word having index OLD did not score the word with index 24
# The model for word having index BORROW did not score the word with index 24
# The model for word having index FIND did not score the word with index 25
# The model for word having index LEG did not score the word with index 25
# The model for word having index CANDY did not score the word with index 25
# The model for word having index OLD did not score the word with index 25
# The model for word having index BORROW did not score the word with index 25
# The model for word having index FIND did not score the word with index 26
# The model for word having index LEG did not score the word with index 26
# The model for word having index CANDY did not score the word with index 26
# The model for word having index OLD did not score the word with index 26
# The model for word having index BORROW did not score the word with index 26
# The model for word having index FIND did not score the word with index 27
# The model for word having index LEG did not score the word with index 27
# The model for word having index CANDY did not score the word with index 27
# The model for word having index OLD did not score the word with index 27
# The model for word having index BORROW did not score the word with index 27
# The model for word having index FIND did not score the word with index 28
# The model for word having index LEG did not score the word with index 28
# The model for word having index CANDY did not score the word with index 28
# The model for word having index OLD did not score the word with index 28
# The model for word having index BORROW did not score the word with index 28
# The model for word having index FIND did not score the word with index 29
# The model for word having index LEG did not score the word with index 29
# The model for word having index CANDY did not score the word with index 29
# The model for word having index OLD did not score the word with index 29
# The model for word having index BORROW did not score the word with index 29
# The model for word having index FIND did not score the word with index 30
# The model for word having index LEG did not score the word with index 30
# The model for word having index CANDY did not score the word with index 30
# The model for word having index OLD did not score the word with index 30
# The model for word having index BORROW did not score the word with index 30
# The model for word having index FIND did not score the word with index 31
# The model for word having index LEG did not score the word with index 31
# The model for word having index CANDY did not score the word with index 31
# The model for word having index OLD did not score the word with index 31
# The model for word having index BORROW did not score the word with index 31
# The model for word having index FIND did not score the word with index 32
# The model for word having index LEG did not score the word with index 32
# The model for word having index CANDY did not score the word with index 32
# The model for word having index OLD did not score the word with index 32
# The model for word having index BORROW did not score the word with index 32
# The model for word having index FIND did not score the word with index 33
# The model for word having index LEG did not score the word with index 33
# The model for word having index CANDY did not score the word with index 33
# The model for word having index OLD did not score the word with index 33
# The model for word having index BORROW did not score the word with index 33
# The model for word having index FIND did not score the word with index 34
# The model for word having index LEG did not score the word with index 34
# The model for word having index CANDY did not score the word with index 34
# The model for word having index OLD did not score the word with index 34
# The model for word having index BORROW did not score the word with index 34
# The model for word having index FIND did not score the word with index 35
# The model for word having index LEG did not score the word with index 35
# The model for word having index CANDY did not score the word with index 35
# The model for word having index OLD did not score the word with index 35
# The model for word having index BORROW did not score the word with index 35
# The model for word having index FIND did not score the word with index 36
# The model for word having index LEG did not score the word with index 36
# The model for word having index CANDY did not score the word with index 36
# The model for word having index OLD did not score the word with index 36
# The model for word having index BORROW did not score the word with index 36
# The model for word having index FIND did not score the word with index 37
# The model for word having index LEG did not score the word with index 37
# The model for word having index CANDY did not score the word with index 37
# The model for word having index OLD did not score the word with index 37
# The model for word having index BORROW did not score the word with index 37
# The model for word having index FIND did not score the word with index 38
# The model for word having index LEG did not score the word with index 38
# The model for word having index CANDY did not score the word with index 38
# The model for word having index OLD did not score the word with index 38
# The model for word having index BORROW did not score the word with index 38
# The model for word having index FIND did not score the word with index 39
# The model for word having index LEG did not score the word with index 39
# The model for word having index CANDY did not score the word with index 39
# The model for word having index OLD did not score the word with index 39
# The model for word having index BORROW did not score the word with index 39
# The model for word having index FIND did not score the word with index 40
# The model for word having index LEG did not score the word with index 40
# The model for word having index CANDY did not score the word with index 40
# The model for word having index OLD did not score the word with index 40
# The model for word having index BORROW did not score the word with index 40
# The model for word having index FIND did not score the word with index 41
# The model for word having index LEG did not score the word with index 41
# The model for word having index CANDY did not score the word with index 41
# The model for word having index OLD did not score the word with index 41
# The model for word having index BORROW did not score the word with index 41
# The model for word having index FIND did not score the word with index 42
# The model for word having index LEG did not score the word with index 42
# The model for word having index CANDY did not score the word with index 42
# The model for word having index OLD did not score the word with index 42
# The model for word having index BORROW did not score the word with index 42
# The model for word having index FIND did not score the word with index 43
# The model for word having index LEG did not score the word with index 43
# The model for word having index CANDY did not score the word with index 43
# The model for word having index OLD did not score the word with index 43
# The model for word having index BORROW did not score the word with index 43
# The model for word having index FIND did not score the word with index 44
# The model for word having index LEG did not score the word with index 44
# The model for word having index CANDY did not score the word with index 44
# The model for word having index OLD did not score the word with index 44
# The model for word having index BORROW did not score the word with index 44
# The model for word having index FIND did not score the word with index 45
# The model for word having index LEG did not score the word with index 45
# The model for word having index CANDY did not score the word with index 45
# The model for word having index OLD did not score the word with index 45
# The model for word having index BORROW did not score the word with index 45
# The model for word having index FIND did not score the word with index 46
# The model for word having index LEG did not score the word with index 46
# The model for word having index CANDY did not score the word with index 46
# The model for word having index OLD did not score the word with index 46
# The model for word having index BORROW did not score the word with index 46
# The model for word having index FIND did not score the word with index 47
# The model for word having index LEG did not score the word with index 47
# The model for word having index CANDY did not score the word with index 47
# The model for word having index OLD did not score the word with index 47
# The model for word having index BORROW did not score the word with index 47
# The model for word having index FIND did not score the word with index 48
# The model for word having index LEG did not score the word with index 48
# The model for word having index CANDY did not score the word with index 48
# The model for word having index OLD did not score the word with index 48
# The model for word having index BORROW did not score the word with index 48
# The model for word having index FIND did not score the word with index 49
# The model for word having index LEG did not score the word with index 49
# The model for word having index CANDY did not score the word with index 49
# The model for word having index OLD did not score the word with index 49
# The model for word having index BORROW did not score the word with index 49
# The model for word having index FIND did not score the word with index 50
# The model for word having index LEG did not score the word with index 50
# The model for word having index CANDY did not score the word with index 50
# The model for word having index OLD did not score the word with index 50
# The model for word having index BORROW did not score the word with index 50
# The model for word having index FIND did not score the word with index 51
# The model for word having index LEG did not score the word with index 51
# The model for word having index CANDY did not score the word with index 51
# The model for word having index OLD did not score the word with index 51
# The model for word having index BORROW did not score the word with index 51
# The model for word having index FIND did not score the word with index 52
# The model for word having index LEG did not score the word with index 52
# The model for word having index CANDY did not score the word with index 52
# The model for word having index OLD did not score the word with index 52
# The model for word having index BORROW did not score the word with index 52
# The model for word having index FIND did not score the word with index 53
# The model for word having index LEG did not score the word with index 53
# The model for word having index CANDY did not score the word with index 53
# The model for word having index OLD did not score the word with index 53
# The model for word having index BORROW did not score the word with index 53
# The model for word having index FIND did not score the word with index 54
# The model for word having index LEG did not score the word with index 54
# The model for word having index CANDY did not score the word with index 54
# The model for word having index OLD did not score the word with index 54
# The model for word having index BORROW did not score the word with index 54
# The model for word having index FIND did not score the word with index 55
# The model for word having index LEG did not score the word with index 55
# The model for word having index CANDY did not score the word with index 55
# The model for word having index OLD did not score the word with index 55
# The model for word having index BORROW did not score the word with index 55
# The model for word having index FIND did not score the word with index 56
# The model for word having index LEG did not score the word with index 56
# The model for word having index CANDY did not score the word with index 56
# The model for word having index OLD did not score the word with index 56
# The model for word having index BORROW did not score the word with index 56
# The model for word having index FIND did not score the word with index 57
# The model for word having index LEG did not score the word with index 57
# The model for word having index CANDY did not score the word with index 57
# The model for word having index OLD did not score the word with index 57
# The model for word having index BORROW did not score the word with index 57
# The model for word having index FIND did not score the word with index 58
# The model for word having index LEG did not score the word with index 58
# The model for word having index CANDY did not score the word with index 58
# The model for word having index OLD did not score the word with index 58
# The model for word having index BORROW did not score the word with index 58
# The model for word having index FIND did not score the word with index 59
# The model for word having index LEG did not score the word with index 59
# The model for word having index CANDY did not score the word with index 59
# The model for word having index OLD did not score the word with index 59
# The model for word having index BORROW did not score the word with index 59
# The model for word having index FIND did not score the word with index 60
# The model for word having index LEG did not score the word with index 60
# The model for word having index CANDY did not score the word with index 60
# The model for word having index OLD did not score the word with index 60
# The model for word having index BORROW did not score the word with index 60
# The model for word having index FIND did not score the word with index 61
# The model for word having index LEG did not score the word with index 61
# The model for word having index CANDY did not score the word with index 61
# The model for word having index OLD did not score the word with index 61
# The model for word having index BORROW did not score the word with index 61
# The model for word having index FIND did not score the word with index 62
# The model for word having index LEG did not score the word with index 62
# The model for word having index CANDY did not score the word with index 62
# The model for word having index OLD did not score the word with index 62
# The model for word having index BORROW did not score the word with index 62
# The model for word having index FIND did not score the word with index 63
# The model for word having index LEG did not score the word with index 63
# The model for word having index CANDY did not score the word with index 63
# The model for word having index OLD did not score the word with index 63
# The model for word having index BORROW did not score the word with index 63
# The model for word having index FIND did not score the word with index 64
# The model for word having index LEG did not score the word with index 64
# The model for word having index CANDY did not score the word with index 64
# The model for word having index OLD did not score the word with index 64
# The model for word having index BORROW did not score the word with index 64
# The model for word having index FIND did not score the word with index 65
# The model for word having index LEG did not score the word with index 65
# The model for word having index CANDY did not score the word with index 65
# The model for word having index OLD did not score the word with index 65
# The model for word having index BORROW did not score the word with index 65
# The model for word having index FIND did not score the word with index 66
# The model for word having index LEG did not score the word with index 66
# The model for word having index CANDY did not score the word with index 66
# The model for word having index OLD did not score the word with index 66
# The model for word having index BORROW did not score the word with index 66
# The model for word having index FIND did not score the word with index 67
# The model for word having index LEG did not score the word with index 67
# The model for word having index CANDY did not score the word with index 67
# The model for word having index OLD did not score the word with index 67
# The model for word having index BORROW did not score the word with index 67
# The model for word having index FIND did not score the word with index 68
# The model for word having index LEG did not score the word with index 68
# The model for word having index CANDY did not score the word with index 68
# The model for word having index OLD did not score the word with index 68
# The model for word having index BORROW did not score the word with index 68
# The model for word having index FIND did not score the word with index 69
# The model for word having index LEG did not score the word with index 69
# The model for word having index CANDY did not score the word with index 69
# The model for word having index OLD did not score the word with index 69
# The model for word having index BORROW did not score the word with index 69
# The model for word having index FIND did not score the word with index 70
# The model for word having index LEG did not score the word with index 70
# The model for word having index CANDY did not score the word with index 70
# The model for word having index OLD did not score the word with index 70
# The model for word having index BORROW did not score the word with index 70
# The model for word having index FIND did not score the word with index 71
# The model for word having index LEG did not score the word with index 71
# The model for word having index CANDY did not score the word with index 71
# The model for word having index OLD did not score the word with index 71
# The model for word having index BORROW did not score the word with index 71
# The model for word having index FIND did not score the word with index 72
# The model for word having index LEG did not score the word with index 72
# The model for word having index CANDY did not score the word with index 72
# The model for word having index OLD did not score the word with index 72
# The model for word having index BORROW did not score the word with index 72
# The model for word having index FIND did not score the word with index 73
# The model for word having index LEG did not score the word with index 73
# The model for word having index CANDY did not score the word with index 73
# The model for word having index OLD did not score the word with index 73
# The model for word having index BORROW did not score the word with index 73
# The model for word having index FIND did not score the word with index 74
# The model for word having index LEG did not score the word with index 74
# The model for word having index CANDY did not score the word with index 74
# The model for word having index OLD did not score the word with index 74
# The model for word having index BORROW did not score the word with index 74
# The model for word having index FIND did not score the word with index 75
# The model for word having index LEG did not score the word with index 75
# The model for word having index CANDY did not score the word with index 75
# The model for word having index OLD did not score the word with index 75
# The model for word having index BORROW did not score the word with index 75
# The model for word having index FIND did not score the word with index 76
# The model for word having index LEG did not score the word with index 76
# The model for word having index CANDY did not score the word with index 76
# The model for word having index OLD did not score the word with index 76
# The model for word having index BORROW did not score the word with index 76
# The model for word having index FIND did not score the word with index 77
# The model for word having index LEG did not score the word with index 77
# The model for word having index CANDY did not score the word with index 77
# The model for word having index OLD did not score the word with index 77
# The model for word having index BORROW did not score the word with index 77
# The model for word having index FIND did not score the word with index 78
# The model for word having index LEG did not score the word with index 78
# The model for word having index CANDY did not score the word with index 78
# The model for word having index OLD did not score the word with index 78
# The model for word having index BORROW did not score the word with index 78
# The model for word having index FIND did not score the word with index 79
# The model for word having index LEG did not score the word with index 79
# The model for word having index CANDY did not score the word with index 79
# The model for word having index OLD did not score the word with index 79
# The model for word having index BORROW did not score the word with index 79
# The model for word having index FIND did not score the word with index 80
# The model for word having index LEG did not score the word with index 80
# The model for word having index CANDY did not score the word with index 80
# The model for word having index OLD did not score the word with index 80
# The model for word having index BORROW did not score the word with index 80
# The model for word having index FIND did not score the word with index 81
# The model for word having index LEG did not score the word with index 81
# The model for word having index CANDY did not score the word with index 81
# The model for word having index OLD did not score the word with index 81
# The model for word having index BORROW did not score the word with index 81
# The model for word having index FIND did not score the word with index 82
# The model for word having index LEG did not score the word with index 82
# The model for word having index CANDY did not score the word with index 82
# The model for word having index OLD did not score the word with index 82
# The model for word having index BORROW did not score the word with index 82
# The model for word having index FIND did not score the word with index 83
# The model for word having index LEG did not score the word with index 83
# The model for word having index CANDY did not score the word with index 83
# The model for word having index OLD did not score the word with index 83
# The model for word having index BORROW did not score the word with index 83
# The model for word having index FIND did not score the word with index 84
# The model for word having index LEG did not score the word with index 84
# The model for word having index CANDY did not score the word with index 84
# The model for word having index OLD did not score the word with index 84
# The model for word having index BORROW did not score the word with index 84
# The model for word having index FIND did not score the word with index 85
# The model for word having index LEG did not score the word with index 85
# The model for word having index CANDY did not score the word with index 85
# The model for word having index OLD did not score the word with index 85
# The model for word having index BORROW did not score the word with index 85
# The model for word having index FIND did not score the word with index 86
# The model for word having index LEG did not score the word with index 86
# The model for word having index CANDY did not score the word with index 86
# The model for word having index OLD did not score the word with index 86
# The model for word having index BORROW did not score the word with index 86
# The model for word having index FIND did not score the word with index 87
# The model for word having index LEG did not score the word with index 87
# The model for word having index CANDY did not score the word with index 87
# The model for word having index OLD did not score the word with index 87
# The model for word having index BORROW did not score the word with index 87
# The model for word having index FIND did not score the word with index 88
# The model for word having index LEG did not score the word with index 88
# The model for word having index CANDY did not score the word with index 88
# The model for word having index OLD did not score the word with index 88
# The model for word having index BORROW did not score the word with index 88
# The model for word having index FIND did not score the word with index 89
# The model for word having index LEG did not score the word with index 89
# The model for word having index CANDY did not score the word with index 89
# The model for word having index OLD did not score the word with index 89
# The model for word having index BORROW did not score the word with index 89
# The model for word having index FIND did not score the word with index 90
# The model for word having index LEG did not score the word with index 90
# The model for word having index CANDY did not score the word with index 90
# The model for word having index OLD did not score the word with index 90
# The model for word having index BORROW did not score the word with index 90
# The model for word having index FIND did not score the word with index 91
# The model for word having index LEG did not score the word with index 91
# The model for word having index CANDY did not score the word with index 91
# The model for word having index OLD did not score the word with index 91
# The model for word having index BORROW did not score the word with index 91
# The model for word having index FIND did not score the word with index 92
# The model for word having index LEG did not score the word with index 92
# The model for word having index CANDY did not score the word with index 92
# The model for word having index OLD did not score the word with index 92
# The model for word having index BORROW did not score the word with index 92
# The model for word having index FIND did not score the word with index 93
# The model for word having index LEG did not score the word with index 93
# The model for word having index CANDY did not score the word with index 93
# The model for word having index OLD did not score the word with index 93
# The model for word having index BORROW did not score the word with index 93
# The model for word having index FIND did not score the word with index 94
# The model for word having index LEG did not score the word with index 94
# The model for word having index CANDY did not score the word with index 94
# The model for word having index OLD did not score the word with index 94
# The model for word having index BORROW did not score the word with index 94
# The model for word having index FIND did not score the word with index 95
# The model for word having index LEG did not score the word with index 95
# The model for word having index CANDY did not score the word with index 95
# The model for word having index OLD did not score the word with index 95
# The model for word having index BORROW did not score the word with index 95
# The model for word having index FIND did not score the word with index 96
# The model for word having index LEG did not score the word with index 96
# The model for word having index CANDY did not score the word with index 96
# The model for word having index OLD did not score the word with index 96
# The model for word having index BORROW did not score the word with index 96
# The model for word having index FIND did not score the word with index 97
# The model for word having index LEG did not score the word with index 97
# The model for word having index CANDY did not score the word with index 97
# The model for word having index OLD did not score the word with index 97
# The model for word having index BORROW did not score the word with index 97
# The model for word having index FIND did not score the word with index 98
# The model for word having index LEG did not score the word with index 98
# The model for word having index CANDY did not score the word with index 98
# The model for word having index OLD did not score the word with index 98
# The model for word having index BORROW did not score the word with index 98
# The model for word having index FIND did not score the word with index 99
# The model for word having index LEG did not score the word with index 99
# The model for word having index CANDY did not score the word with index 99
# The model for word having index OLD did not score the word with index 99
# The model for word having index BORROW did not score the word with index 99
# The model for word having index FIND did not score the word with index 100
# The model for word having index LEG did not score the word with index 100
# The model for word having index CANDY did not score the word with index 100
# The model for word having index OLD did not score the word with index 100
# The model for word having index BORROW did not score the word with index 100
# The model for word having index FIND did not score the word with index 101
# The model for word having index LEG did not score the word with index 101
# The model for word having index CANDY did not score the word with index 101
# The model for word having index OLD did not score the word with index 101
# The model for word having index BORROW did not score the word with index 101
# The model for word having index FIND did not score the word with index 102
# The model for word having index LEG did not score the word with index 102
# The model for word having index CANDY did not score the word with index 102
# The model for word having index OLD did not score the word with index 102
# The model for word having index BORROW did not score the word with index 102
# The model for word having index FIND did not score the word with index 103
# The model for word having index LEG did not score the word with index 103
# The model for word having index CANDY did not score the word with index 103
# The model for word having index OLD did not score the word with index 103
# The model for word having index BORROW did not score the word with index 103
# The model for word having index FIND did not score the word with index 104
# The model for word having index LEG did not score the word with index 104
# The model for word having index CANDY did not score the word with index 104
# The model for word having index OLD did not score the word with index 104
# The model for word having index BORROW did not score the word with index 104
# The model for word having index FIND did not score the word with index 105
# The model for word having index LEG did not score the word with index 105
# The model for word having index CANDY did not score the word with index 105
# The model for word having index OLD did not score the word with index 105
# The model for word having index BORROW did not score the word with index 105
# The model for word having index FIND did not score the word with index 106
# The model for word having index LEG did not score the word with index 106
# The model for word having index CANDY did not score the word with index 106
# The model for word having index OLD did not score the word with index 106
# The model for word having index BORROW did not score the word with index 106
# The model for word having index FIND did not score the word with index 107
# The model for word having index LEG did not score the word with index 107
# The model for word having index CANDY did not score the word with index 107
# The model for word having index OLD did not score the word with index 107
# The model for word having index BORROW did not score the word with index 107
# The model for word having index FIND did not score the word with index 108
# The model for word having index LEG did not score the word with index 108
# The model for word having index CANDY did not score the word with index 108
# The model for word having index OLD did not score the word with index 108
# The model for word having index BORROW did not score the word with index 108
# The model for word having index FIND did not score the word with index 109
# The model for word having index LEG did not score the word with index 109
# The model for word having index CANDY did not score the word with index 109
# The model for word having index OLD did not score the word with index 109
# The model for word having index BORROW did not score the word with index 109
# The model for word having index FIND did not score the word with index 110
# The model for word having index LEG did not score the word with index 110
# The model for word having index CANDY did not score the word with index 110
# The model for word having index OLD did not score the word with index 110
# The model for word having index BORROW did not score the word with index 110
# The model for word having index FIND did not score the word with index 111
# The model for word having index LEG did not score the word with index 111
# The model for word having index CANDY did not score the word with index 111
# The model for word having index OLD did not score the word with index 111
# The model for word having index BORROW did not score the word with index 111
# The model for word having index FIND did not score the word with index 112
# The model for word having index LEG did not score the word with index 112
# The model for word having index CANDY did not score the word with index 112
# The model for word having index OLD did not score the word with index 112
# The model for word having index BORROW did not score the word with index 112
# The model for word having index FIND did not score the word with index 113
# The model for word having index LEG did not score the word with index 113
# The model for word having index CANDY did not score the word with index 113
# The model for word having index OLD did not score the word with index 113
# The model for word having index BORROW did not score the word with index 113
# The model for word having index FIND did not score the word with index 114
# The model for word having index LEG did not score the word with index 114
# The model for word having index CANDY did not score the word with index 114
# The model for word having index OLD did not score the word with index 114
# The model for word having index BORROW did not score the word with index 114
# The model for word having index FIND did not score the word with index 115
# The model for word having index LEG did not score the word with index 115
# The model for word having index CANDY did not score the word with index 115
# The model for word having index OLD did not score the word with index 115
# The model for word having index BORROW did not score the word with index 115
# The model for word having index FIND did not score the word with index 116
# The model for word having index LEG did not score the word with index 116
# The model for word having index CANDY did not score the word with index 116
# The model for word having index OLD did not score the word with index 116
# The model for word having index BORROW did not score the word with index 116
# The model for word having index FIND did not score the word with index 117
# The model for word having index LEG did not score the word with index 117
# The model for word having index CANDY did not score the word with index 117
# The model for word having index OLD did not score the word with index 117
# The model for word having index BORROW did not score the word with index 117
# The model for word having index FIND did not score the word with index 118
# The model for word having index LEG did not score the word with index 118
# The model for word having index CANDY did not score the word with index 118
# The model for word having index OLD did not score the word with index 118
# The model for word having index BORROW did not score the word with index 118
# The model for word having index FIND did not score the word with index 119
# The model for word having index LEG did not score the word with index 119
# The model for word having index CANDY did not score the word with index 119
# The model for word having index OLD did not score the word with index 119
# The model for word having index BORROW did not score the word with index 119
# The model for word having index FIND did not score the word with index 120
# The model for word having index LEG did not score the word with index 120
# The model for word having index CANDY did not score the word with index 120
# The model for word having index OLD did not score the word with index 120
# The model for word having index BORROW did not score the word with index 120
# The model for word having index FIND did not score the word with index 121
# The model for word having index LEG did not score the word with index 121
# The model for word having index CANDY did not score the word with index 121
# The model for word having index OLD did not score the word with index 121
# The model for word having index BORROW did not score the word with index 121
# The model for word having index FIND did not score the word with index 122
# The model for word having index LEG did not score the word with index 122
# The model for word having index CANDY did not score the word with index 122
# The model for word having index OLD did not score the word with index 122
# The model for word having index BORROW did not score the word with index 122
# The model for word having index FIND did not score the word with index 123
# The model for word having index LEG did not score the word with index 123
# The model for word having index CANDY did not score the word with index 123
# The model for word having index OLD did not score the word with index 123
# The model for word having index BORROW did not score the word with index 123
# The model for word having index FIND did not score the word with index 124
# The model for word having index LEG did not score the word with index 124
# The model for word having index CANDY did not score the word with index 124
# The model for word having index OLD did not score the word with index 124
# The model for word having index BORROW did not score the word with index 124
# The model for word having index FIND did not score the word with index 125
# The model for word having index LEG did not score the word with index 125
# The model for word having index CANDY did not score the word with index 125
# The model for word having index OLD did not score the word with index 125
# The model for word having index BORROW did not score the word with index 125
# The model for word having index FIND did not score the word with index 126
# The model for word having index LEG did not score the word with index 126
# The model for word having index CANDY did not score the word with index 126
# The model for word having index OLD did not score the word with index 126
# The model for word having index BORROW did not score the word with index 126
# The model for word having index FIND did not score the word with index 127
# The model for word having index LEG did not score the word with index 127
# The model for word having index CANDY did not score the word with index 127
# The model for word having index OLD did not score the word with index 127
# The model for word having index BORROW did not score the word with index 127
# The model for word having index FIND did not score the word with index 128
# The model for word having index LEG did not score the word with index 128
# The model for word having index CANDY did not score the word with index 128
# The model for word having index OLD did not score the word with index 128
# The model for word having index BORROW did not score the word with index 128
# ...
# The model for word having index FIND did not score the word with index 136
# The model for word having index LEG did not score the word with index 136
# The model for word having index CANDY did not score the word with index 136
# The model for word having index OLD did not score the word with index 136
# The model for word having index BORROW did not score the word with index 136
# The model for word having index FIND did not score the word with index 137
# The model for word having index LEG did not score the word with index 137
# The model for word having index CANDY did not score the word with index 137
# The model for word having index OLD did not score the word with index 137
# The model for word having index BORROW did not score the word with index 137
# The model for word having index FIND did not score the word with index 138
# The model for word having index LEG did not score the word with index 138
# The model for word having index CANDY did not score the word with index 138
# The model for word having index OLD did not score the word with index 138
# The model for word having index BORROW did not score the word with index 138
# The model for word having index FIND did not score the word with index 139
# The model for word having index LEG did not score the word with index 139
# The model for word having index CANDY did not score the word with index 139
# The model for word having index OLD did not score the word with index 139
# The model for word having index BORROW did not score the word with index 139
# The model for word having index FIND did not score the word with index 140
# The model for word having index LEG did not score the word with index 140
# The model for word having index CANDY did not score the word with index 140
# The model for word having index OLD did not score the word with index 140
# The model for word having index BORROW did not score the word with index 140
# The model for word having index FIND did not score the word with index 141
# The model for word having index LEG did not score the word with index 141
# The model for word having index CANDY did not score the word with index 141
# The model for word having index OLD did not score the word with index 141
# The model for word having index BORROW did not score the word with index 141
# The model for word having index FIND did not score the word with index 142
# The model for word having index LEG did not score the word with index 142
# The model for word having index CANDY did not score the word with index 142
# The model for word having index OLD did not score the word with index 142
# The model for word having index BORROW did not score the word with index 142
# The model for word having index FIND did not score the word with index 143
# The model for word having index LEG did not score the word with index 143
# The model for word having index CANDY did not score the word with index 143
# The model for word having index OLD did not score the word with index 143
# The model for word having index BORROW did not score the word with index 143
# The model for word having index FIND did not score the word with index 144
# The model for word having index LEG did not score the word with index 144
# The model for word having index CANDY did not score the word with index 144
# The model for word having index OLD did not score the word with index 144
# The model for word having index BORROW did not score the word with index 144
# The model for word having index FIND did not score the word with index 145
# The model for word having index LEG did not score the word with index 145
# The model for word having index CANDY did not score the word with index 145
# The model for word having index OLD did not score the word with index 145
# The model for word having index BORROW did not score the word with index 145
# The model for word having index FIND did not score the word with index 146
# The model for word having index LEG did not score the word with index 146
# The model for word having index CANDY did not score the word with index 146
# The model for word having index OLD did not score the word with index 146
# The model for word having index BORROW did not score the word with index 146
# The model for word having index FIND did not score the word with index 147
# The model for word having index LEG did not score the word with index 147
# The model for word having index CANDY did not score the word with index 147
# The model for word having index OLD did not score the word with index 147
# The model for word having index BORROW did not score the word with index 147
# The model for word having index FIND did not score the word with index 148
# The model for word having index LEG did not score the word with index 148
# The model for word having index CANDY did not score the word with index 148
# The model for word having index OLD did not score the word with index 148
# The model for word having index BORROW did not score the word with index 148
# The model for word having index FIND did not score the word with index 149
# The model for word having index LEG did not score the word with index 149
# The model for word having index CANDY did not score the word with index 149
# The model for word having index OLD did not score the word with index 149
# The model for word having index BORROW did not score the word with index 149
# The model for word having index FIND did not score the word with index 150
# The model for word having index LEG did not score the word with index 150
# The model for word having index CANDY did not score the word with index 150
# The model for word having index OLD did not score the word with index 150
# The model for word having index BORROW did not score the word with index 150
# The model for word having index FIND did not score the word with index 151
# The model for word having index LEG did not score the word with index 151
# The model for word having index CANDY did not score the word with index 151
# The model for word having index OLD did not score the word with index 151
# The model for word having index BORROW did not score the word with index 151
# The model for word having index FIND did not score the word with index 152
# The model for word having index LEG did not score the word with index 152
# The model for word having index CANDY did not score the word with index 152
# The model for word having index OLD did not score the word with index 152
# The model for word having index BORROW did not score the word with index 152
# The model for word having index FIND did not score the word with index 153
# The model for word having index LEG did not score the word with index 153
# The model for word having index CANDY did not score the word with index 153
# The model for word having index OLD did not score the word with index 153
# The model for word having index BORROW did not score the word with index 153
# The model for word having index FIND did not score the word with index 154
# The model for word having index LEG did not score the word with index 154
# The model for word having index CANDY did not score the word with index 154
# The model for word having index OLD did not score the word with index 154
# The model for word having index BORROW did not score the word with index 154
# The model for word having index FIND did not score the word with index 155
# The model for word having index LEG did not score the word with index 155
# The model for word having index CANDY did not score the word with index 155
# The model for word having index OLD did not score the word with index 155
# The model for word having index BORROW did not score the word with index 155
# The model for word having index FIND did not score the word with index 156
# The model for word having index LEG did not score the word with index 156
# The model for word having index CANDY did not score the word with index 156
# The model for word having index OLD did not score the word with index 156
# The model for word having index BORROW did not score the word with index 156
# The model for word having index FIND did not score the word with index 157
# The model for word having index LEG did not score the word with index 157
# The model for word having index CANDY did not score the word with index 157
# The model for word having index OLD did not score the word with index 157
# The model for word having index BORROW did not score the word with index 157
# The model for word having index FIND did not score the word with index 158
# The model for word having index LEG did not score the word with index 158
# The model for word having index CANDY did not score the word with index 158
# The model for word having index OLD did not score the word with index 158
# The model for word having index BORROW did not score the word with index 158
# The model for word having index FIND did not score the word with index 159
# The model for word having index LEG did not score the word with index 159
# The model for word having index CANDY did not score the word with index 159
# The model for word having index OLD did not score the word with index 159
# The model for word having index BORROW did not score the word with index 159
# The model for word having index FIND did not score the word with index 160
# The model for word having index LEG did not score the word with index 160
# The model for word having index CANDY did not score the word with index 160
# The model for word having index OLD did not score the word with index 160
# The model for word having index BORROW did not score the word with index 160
# The model for word having index FIND did not score the word with index 161
# The model for word having index LEG did not score the word with index 161
# The model for word having index CANDY did not score the word with index 161
# The model for word having index OLD did not score the word with index 161
# The model for word having index BORROW did not score the word with index 161
# The model for word having index FIND did not score the word with index 162
# The model for word having index LEG did not score the word with index 162
# The model for word having index CANDY did not score the word with index 162
# The model for word having index OLD did not score the word with index 162
# The model for word having index BORROW did not score the word with index 162
# The model for word having index FIND did not score the word with index 163
# The model for word having index LEG did not score the word with index 163
# The model for word having index CANDY did not score the word with index 163
# The model for word having index OLD did not score the word with index 163
# The model for word having index BORROW did not score the word with index 163
# The model for word having index FIND did not score the word with index 164
# The model for word having index LEG did not score the word with index 164
# The model for word having index CANDY did not score the word with index 164
# The model for word having index OLD did not score the word with index 164
# The model for word having index BORROW did not score the word with index 164
# The model for word having index FIND did not score the word with index 165
# The model for word having index LEG did not score the word with index 165
# The model for word having index CANDY did not score the word with index 165
# The model for word having index OLD did not score the word with index 165
# The model for word having index BORROW did not score the word with index 165
# The model for word having index FIND did not score the word with index 166
# The model for word having index LEG did not score the word with index 166
# The model for word having index CANDY did not score the word with index 166
# The model for word having index OLD did not score the word with index 166
# The model for word having index BORROW did not score the word with index 166
# The model for word having index FIND did not score the word with index 167
# The model for word having index LEG did not score the word with index 167
# The model for word having index CANDY did not score the word with index 167
# The model for word having index OLD did not score the word with index 167
# The model for word having index BORROW did not score the word with index 167
# The model for word having index FIND did not score the word with index 168
# The model for word having index LEG did not score the word with index 168
# The model for word having index CANDY did not score the word with index 168
# The model for word having index OLD did not score the word with index 168
# The model for word having index BORROW did not score the word with index 168
# The model for word having index FIND did not score the word with index 169
# The model for word having index LEG did not score the word with index 169
# The model for word having index CANDY did not score the word with index 169
# The model for word having index OLD did not score the word with index 169
# The model for word having index BORROW did not score the word with index 169
# The model for word having index FIND did not score the word with index 170
# The model for word having index LEG did not score the word with index 170
# The model for word having index CANDY did not score the word with index 170
# The model for word having index OLD did not score the word with index 170
# The model for word having index BORROW did not score the word with index 170
# The model for word having index FIND did not score the word with index 171
# The model for word having index LEG did not score the word with index 171
# The model for word having index CANDY did not score the word with index 171
# The model for word having index OLD did not score the word with index 171
# The model for word having index BORROW did not score the word with index 171
# The model for word having index FIND did not score the word with index 172
# The model for word having index LEG did not score the word with index 172
# The model for word having index CANDY did not score the word with index 172
# The model for word having index OLD did not score the word with index 172
# The model for word having index BORROW did not score the word with index 172
# The model for word having index FIND did not score the word with index 173
# The model for word having index LEG did not score the word with index 173
# The model for word having index CANDY did not score the word with index 173
# The model for word having index OLD did not score the word with index 173
# The model for word having index BORROW did not score the word with index 173
# The model for word having index FIND did not score the word with index 174
# The model for word having index LEG did not score the word with index 174
# The model for word having index CANDY did not score the word with index 174
# The model for word having index OLD did not score the word with index 174
# The model for word having index BORROW did not score the word with index 174
# The model for word having index FIND did not score the word with index 175
# The model for word having index LEG did not score the word with index 175
# The model for word having index CANDY did not score the word with index 175
# The model for word having index OLD did not score the word with index 175
# The model for word having index BORROW did not score the word with index 175
# The model for word having index FIND did not score the word with index 176
# The model for word having index LEG did not score the word with index 176
# The model for word having index CANDY did not score the word with index 176
# The model for word having index OLD did not score the word with index 176
# The model for word having index BORROW did not score the word with index 176
# The model for word having index FIND did not score the word with index 177
# The model for word having index LEG did not score the word with index 177
# The model for word having index CANDY did not score the word with index 177
# The model for word having index OLD did not score the word with index 177
# .
# The model for word having index BORROW did not score the word with index 177
# ----------------------------------------------------------------------
# Ran 2 tests in 47.841s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# <a id='part4_info'></a>
# ## PART 4: (OPTIONAL)  Improve the WER with Language Models
# We've squeezed just about as much as we can out of the model and still only get about 50% of the words right! Surely we can do better than that.  Probability to the rescue again in the form of [statistical language models (SLM)](https://en.wikipedia.org/wiki/Language_model).  The basic idea is that each word has some probability of occurrence within the set, and some probability that it is adjacent to specific other words. We can use that additional information to make better choices.
#
# ##### Additional reading and resources
# - [Introduction to N-grams (Stanford Jurafsky slides)](https://web.stanford.edu/class/cs124/lec/languagemodeling.pdf)
# - [Speech Recognition Techniques for a Sign Language Recognition System, Philippe Dreuw et al](https://www-i6.informatik.rwth-aachen.de/publications/download/154/Dreuw--2007.pdf) see the improved results of applying LM on *this* data!
# - [SLM data for *this* ASL dataset](ftp://wasserstoff.informatik.rwth-aachen.de/pub/rwth-boston-104/lm/)
#
# ##### Optional challenge
# The recognizer you implemented in Part 3 is equivalent to a "0-gram" SLM.  Improve the WER with the SLM data provided with the data set in the link above using "1-gram", "2-gram", and/or "3-gram" statistics. The `probabilities` data you've already calculated will be useful and can be turned into a pandas DataFrame if desired (see next cell).
# Good luck!  Share your results with the class!

# %%
# create a DataFrame of log likelihoods for the test word items
df_probs = pd.DataFrame(data=probabilities)
df_probs.head()
